# %% [raw]
# Date file : Houston_texa.osm (624MB)

# %% [markdown]
# Author: Yepeng Li

# %% [markdown]
# # 1.Data wrangling process

# %%
import xml.etree.cElementTree as ET 
from collections import defaultdict 
import re 
import pprint 
import codecs 
import json

# %%
OSMFILE = "Houston_texas.osm" 
CREATED = [ "version", "changeset", "timestamp", "user", "uid"]

# %%
infile = OSMFILE

# %%
#pre-compiled regex queries 
street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE) 
lower = re.compile(r'^([a-z]|_)*$') 
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$') 
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

# %% [markdown]
# # Data overview

# %% [raw]
# File sizes
# Houston_texas.osm ......... 624 MB
# Houston_texas.osm.json .... 710 MB

# %%
# Identify number of tags in osm file 
def count_tags(filename):  
    #initialize defaultdict to avoid KeyError and allow new keys not found in dictionary yet 
    tags = defaultdict(int) 
    #iterate through each node element and increment the dictionary value for that node.tag key 
    for event, node in ET.iterparse(filename): 
        if event == 'end':  
            tags[node.tag]+=1 
        # discard the element is needed to clear from memory and speed up processing 
        node.clear()              
    return tags 
 
tags = count_tags('Houston_texas.osm') 
pprint.pprint(tags)
# Out:
# defaultdict(<type 'int'>, {'node': 2865568, 'nd': 3410766, 'bounds': 1, 'member': 27143, 'tag': 2059263, 'relation': 2362, 'way': 344212, 'osm': 1})

# %%
# Identify Key Type Errors 
# Identify errors function 
# Used by count_key_kinks()
lower = re.compile(r'^([a-z]|_)*$') 
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$') 
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]') 

def key_type(element, keys): 
    if element.tag == "tag": 
        if re.search(lower, element.attrib['k']):         
            keys['lower'] += 1             
        elif re.search(lower_colon, element.attrib['k']): 
            keys['lower_colon'] += 1             
        elif re.search(problemchars, element.attrib['k']): 
            keys['problemchars'] += 1 
            #print out any values with problematic characters 
            #print element             
            print element.attrib['k']             
        else: 
            keys['other'] += 1                       
    return keys 
 
def count_key_kinks(filename): 
    #initialize dictionary 
    keys = {"lower": 0, "lower_colon": 0, "problemchars": 0, "other": 0} 
    for _, element in ET.iterparse(filename): 
        keys = key_type(element, keys) 
        # discard the element is needed to clear from memory and speed up processing 
        element.clear() 
    return keys  
 
keys = count_key_kinks('Houston_texas.osm') 
pprint.pprint(keys)
# Out:
# service area
# service area
# {'lower': 839457, 'lower_colon': 1164223, 'other': 55581, 'problemchars': 2}

# %%
# Identify unique contributors in osm file 
def unique_users(filename): 
    users = set() 
    for _, element in ET.iterparse(filename): 
        try: 
            users.add(element.attrib['uid']) 
        except KeyError: 
            pass 
        element.clear() #to clear memory 
    return users 
 
users = unique_users('Houston_texas.osm') 
print len(users)
# Out:
# 1293

# %% [markdown]
# # Data Auditting and updating

# %%
# List of the street types we expect to see in the US
expected = ["Street", "Avenue", "Boulevard", "Drive", "Court", "Place", "Square", "Lane", "Road",  
            "Trail", "Parkway", "Commons", "Ring Road"]

# %%
# Map the 'incorrect' street abbrvs with the correct street names
# Update the mapping by audit street report

Street_mapping = {'AVE': 'Avenue',
 'AVENUE': 'Avenue',
 'Ave': 'Avenue',
 'Ave.': 'Avenue',
 'Blvd': 'Boulevard',
 'Blvd.': 'Boulevard',
 'Broadway': 'Broadway',
 'Bypass': 'Bypass',
 'Circle': 'Circle',
 'Crossing': 'Crossing',
 'Cypress': 'Cypress',
 'DRIVE': 'Drive',
 'Dr': 'Drive',
 'E': 'East',
 'East':'East',
 'Freeway':'Freeway',
 'Frwy':'Freeway',
 'Fwy': 'Freeway',
 'Highway': 'Highway',
 'Ln': 'Lane',
 'Loop': 'Loop',
 'N': 'North',
 'North':'North',
 'Pkwy': 'Parkway',
 'Rd': 'Road',
 'Rd.': 'Road',
 'Riverway': 'Riverway',
 'Road)': 'Road',
 'S': 'South',
 'ST': 'Street',
 'South': 'South',
 'Speedway': 'Speedway',
 'St': 'Street',
 'St.': 'Street',
 'Stree': 'Street',
 'Way': 'Way',
 'West': 'West',
 'blvd': 'Boulevard',
 'street': 'Street',
}

# %%
#Mapping postal_code according to the audit postal code report

postal_code_mapping = {'77007-2121': '77007','77005-1890': '77005', '77339-1510': '77339', 
'77027-6850': '77027', '77007-2112': '77007','77007-2113': '77007', 'TX 77009': '77009',
'77025-9998': '77025','77019-1999': '77019', '77042-9998': '77042', 'Weslayan Street': '71000',
'77054-1921': '77054', '77024-8022': '77024', '77478-': '77478', '77036-3590': '77036', '7-': '71000', 
'77077-9998': '77077','TX 77494':'77494','TX 77086':'77086','77584-':'77584','77459-':'77459',
'773867386':'77386', 
}
default_phone_number = "+" + "1 " + "8888888888"

# %%
# Add error street names to street_type
def audit_street_type(street_types, street_name): 
    m = street_type_re.search(street_name) 
    if m: 
        street_type = m.group() 
        if street_type not in expected:
            street_types[street_type].add(street_name)

# %%
# Add error postal codes to postcodes. Form example ['adcbe', '564324', '123lf'] 
def audit_postal_code(invalid_postal_codes, postal_code): 
    try: 
        if postal_code[0]== 'u' or postal_code.isdigit() == False or len(postal_code) != 5 : 
            raise ValueError 
    except ValueError: 
        invalid_postal_codes[postal_code] += 1

# %%
# Add error phone number or phone number without country code to invalid phone numbers
def audit_phone_number(invalid_phone_numbers, phone_number): 
    try: 
        if phone_number[:2] != '+1': 
            raise ValueError 
        elif len(phone_number) > 17:      # eg +1 (888)-888-888888
            raise ValueError
    except ValueError: 
        invalid_phone_numbers[phone_number] += 1

# %%
def is_street_name(elem): 
    return (elem.attrib['k'] == "addr:street") 
 
def is_postal_code(elem): 
    return (elem.attrib['k'] == "addr:postcode") 

def is_phone_number(elem): 
    return (elem.attrib['k'] == "phone")

# %%
def audit(osmfile): 
    osm_file = open(osmfile, "r") 
    street_types = defaultdict(set) 
    invalid_postal_codes = defaultdict(int) 
    invalid_phone_numbers = defaultdict(int) 
    for event, elem in ET.iterparse(osm_file, events=("start",)): 
        if elem.tag == "node" or elem.tag == "way": 
            for tag in elem.iter("tag"): 
                if is_street_name(tag): 
                    audit_street_type(street_types, tag.attrib['v']) 
                elif is_postal_code(tag): 
                    audit_postal_code(invalid_postal_codes, tag.attrib['v']) 
                elif is_phone_number(tag): 
                    audit_phone_number(invalid_phone_numbers, tag.attrib['v']) 
    return [invalid_postal_codes, invalid_phone_numbers, street_types]

# %%
#standardizes street types with a replacement map 
def update_name(name, mapping): 
    name = name.split(' ') 
    type = name[-1] 
    if type in mapping: 
        name[-1] = mapping[type] 
        name = ' '.join(name) 
        name = name.title() 
    return name

# %%
#checks if postal code within valid range, if not replaces with 11000 default    
def update_postal_code(postal_code,mapping): 
    try: 
        if len(postal_code) != 5: 
            raise ValueError 
        else: 
            return int(postal_code) 
    except ValueError: 
        type = postal_code
        if type in mapping: 
            postal_code = mapping[type] 
        return postal_code

# %%
#standardizes phone number formatting 
def update_phone_number(phone_number): 
    phone_number = phone_number.translate(None, ' ()-')
    if len(phone_number) > 10:
        return default_phone_number
    else:
        phone_number = '+1 ' + phone_number
        return phone_number

# %%
def shape_element(e): 
    node = {} 
    node['created'] = {} 
    node['pos'] = [0,0] 
    if e.tag == "way": 
        node['node_refs'] = [] 
    if e.tag == "node" or e.tag == "way" : 
        node['type'] = e.tag 
        #attributes 
        for k, v in e.attrib.iteritems(): 
            #latitude 
            if k == 'lat': 
                try: 
                    lat = float(v) 
                    node['pos'][0] = lat 
                except ValueError: 
                    pass 
            #longitude 
            elif k == 'lon': 
                try: 
                    lon = float(v) 
                    node['pos'][1] = lon 
                except ValueError: 
                    pass 
            #creation metadata 
            elif k in CREATED: 
                node['created'][k] = v 
            else: 
                node[k] = v 
        #children 
        for tag in e.iter('tag'): 
            k = tag.attrib['k'] 
            v = tag.attrib['v'] 
            if problemchars.match(k): 
                continue 
            elif lower_colon.match(k): 
                k_split = k.split(':') 
                #address fields 
                if k_split[0] == 'addr': 
                    k_item = k_split[1] 
                    if 'address' not in node: 
                        node['address'] = {} 
                    #streets 
                    if k_item == 'street': 
                        v = update_name(v, Street_mapping)                     
                    #postal codes 
                    if k_item == 'postcode': 
                        v = update_postal_code(v,postal_code_mapping) 
                    node['address'][k_item] = v 
                    continue 
            else:                 
                #phone numbers 
                if(is_phone_number(tag)): 
                    v = update_phone_number(v) 
            node[k] = v 
        #way children 
        if e.tag == "way": 
            for n in e.iter('nd'): 
                ref = n.attrib['ref'] 
                node['node_refs'].append(ref); 
        return node 
    else: 
        return None

# %%
def process_map(file_in, pretty = False): 
    file_out = "{0}.json".format(file_in) 
    data = [] 
    with codecs.open(file_out, "w") as fo: 
        for _, element in ET.iterparse(file_in): 
            el = shape_element(element) 
            if el: 
                data.append(el) 
                if pretty: 
                    fo.write(json.dumps(el, indent=2)+"\n") 
                else: 
                    fo.write(json.dumps(el) + "\n") 
    return data

# %%
def audit_report(): 
    audit_data = audit(OSMFILE) 
    pprint.pprint(audit_data[0]) 
    pprint.pprint(audit_data[1]) 
    pprint.pprint(dict(audit_data[2]))

# %%
audit_report()
# Out:
# defaultdict(<type 'int'>, {'77007-2121': 1, '77054-1921': 1, '773345': 2, '77042-9998': 1, '77077-9998': 1, '77339-1510': 3, '77027-6850': 1, '77019-1999': 1, '77007-2112': 1, '77007-2113': 2, '7-': 1, 'TX 77009': 1, 'TX 77494': 1, '77005-1890': 1, 'TX 77086': 1, '77584-': 1, '77024-8022': 2, '773867386': 1, 'Weslayan Street': 1, '77478-': 1, '77025-9998': 1, '77036-3590': 1})
# defaultdict(<type 'int'>, {'(281) 996-9967': 1, '713-472-5172': 1, '281-497-0630': 1, '(281) 809-9779': 1, '713-284-1200': 1, '713-721-0011': 1, '713-284-1204': 1, '(281) 370-2072': 1, '(281) 320-3700': 1, '(281) 717-8209': 1, '281-634-0612': 1, '281-579-3890': 1, '(281) 242-2424': 1, '(281) 693-0603': 1, '281-578-5566': 1, '(281) 351-1972': 1, '(713) 847-0071': 1, '281-367-5870': 1, '(713) 718-7800': 1, '(713) 743-4646': 1, '(281) 497-8479': 1, '(713) 278-8450': 1, '(713) 718-2000': 1, '(281) 776-0143': 1, '(713) 293-6100': 1, '713-667-1167': 1, '713 790 0099': 1, '(800) 553-2128': 1, '(713) 743-8888': 1, '(281) 828-8880': 1, '832-460-3747': 1, '281-203-5641': 1, '(281) 291-9290': 1, '(281) 487-6170': 1, '(281) 378-3359': 1, '(281) 239-2055': 1, '281-277-1818': 1, '(713) 529-3535': 1, '(713) 743-9450': 1, '(281) 599-0958': 1, '713-224-6400': 1, '936-321-4447': 1, '(979) 245-2990': 1, '(281) 374-6464': 1, '281-589-3600': 1, '(281) 340-1500': 1, '(281) 980-8322': 1, '281-259-0039': 1, '(936) 202-3100': 1, '(713) 741-8558': 1, '(281) 232-1230': 1, '(800) 582-4673': 1, '(713) 996-0009': 1, '(281) 277-2242': 1, '(281) 599-0045': 1, '(281) 275-2825': 1, '832 437 1141': 1, '713-295-5215': 1, '(832) 486-9086': 1, '(713) 743-4820': 4, '(832) 667-1400': 1, '(713) 743-3001': 1, '281-585-3531': 1, '(281) 361-0342': 1, '281-980-4141': 1, '281-257-5551': 1, '713 787 9637': 1, '713-721-0052': 1, '(281) 930 - 9366': 1, '(281) 364-7744': 1, '(832) 287-5577': 1, '281-362-7431': 1, '(713) 743-4746': 1, '(713) 743-4747': 1, '(713) 551-7161': 1, '(281) 440-0522': 1, '713-225-5656': 1, '(713) 524-3305': 1, '(281) 403-2172': 1, '(713) 652-9400': 1, '281-362-1121': 1, '281-538-2504': 1, '(713) 529-2475': 1, '(281) 292-0774': 1, '832-239-9889': 1, '281-538-2500': 1, '713-936-3158': 6, '(713) 743-2255': 1, '(713) 360-7947': 1, '281-858-9026': 1, '713-465-3408': 1, '855-621-4823': 1, '713-636-9776': 1, '281-875-2222': 1, '713-224-7500': 1, '281-340-3100': 4, '281-280-3104': 1, '281-280-3100': 1, '(832) 934 - 3400': 1, '(979) 345-6950': 1, '713-224-4976': 1, '(281) 240-7700': 1, '(713) 807-8226': 1, '(713) 743-9111': 1, '(713) 747-7383': 1, '713-668-4778': 1, '(281) 249-4700': 1, '713-729-7880': 1, '(713) 807-7293': 1, '(281) 778-1300': 1, '800-410-2708': 1, '713-528-0470': 1, '(281) 894-7094': 1, '(281) 859-9381': 1, '(281) 516-2184': 1, '(713) 527-9929': 1, '713-292-5000': 1, '(713) 743-4871': 1, '+01 713 8933102': 1, '(281) 899-3400': 1, '409-744-0413': 1, '281-367-1492': 1, '(281) 497-7991': 1, '(409) 948-9500': 1, '281-499-3511': 1, '(281) 292-0556': 1, '281-504-0285': 1, '(281) 374-7727': 1, '(281) 807-9095': 1, '(281) 331-4545': 1, '(713) 218-1850': 1, '(281) 255-2250': 1, '866-792-3951': 1, '(281) 205-0532': 1, '832-265-0008': 1, '(281) 829-2565': 1, '281-412-9630': 1, '(713) 662-0570': 1, '(281) 930 - 0326': 1, '281-238-8231': 1, '(281) 564-5209': 1, '(281) 564-5201': 1, '(713) 939-0800': 1, '(281) 857-6756': 1, '281-440-1402': 1, '713-464-1200': 1, '281-634-2150': 1, '(832) 842-6120': 1, '281-353-8100': 1, '281-855-9774': 1, '713-365-6700': 1, '(979) 849-3572': 1, '713-365-6705': 1, '(281) 345-1264': 1, '713-223-3456': 1, '(713) 338-2087': 1, '(281) 894-5361': 1, '281-517-1800': 1, '800-548-2510': 1, '(281) 257-4600': 1, '(713) 783-2800': 1, '210-222-1984': 1, '713-668-9820': 1, '(281) 491-4204': 1, '(713) 522-2365': 1, '713-331-1053': 1, '(713) 743-0700': 1, '(281) 746-3644': 1, '(713) 578-6100': 1, '(281) 721-1600': 1, '713-229-8181': 1, '281-360-5100': 1, '281-363-5142': 1, '(281) 304-0859': 1, '(800) 435-9165': 1, '800-458-6340': 1, '281-358-1155': 1, '(832) 237-4860': 1, '(713) 743-3016': 1, '(281) 634-0200': 1, '(713) 659-2000': 1, '713-224-6133': 1, '281-532-5529': 1, '(281) 239-2050': 1, '+001 713-459-4669': 1, '281-240-2000': 2, '(281) 277-5353': 1, '713-964-3155': 1, '(713) 532-5566': 1, '(713) 743-4752': 1, '(800) 396-8530': 1, '713-659-2700': 1, '281-578-3888': 1, '(281) 540-0020': 1, '281-808-3431': 2, '281-758-0471': 1, '(281) 29 ...
# {'1/2': set(['Avenue M 1/2', 'Avenue R 1/2']),
#  '10': set(['I 10']),
#  '110': set(['Memorial Drive, Ste 110']),
#  '1142': set(['Lake Woodlands Drive #1142']),
#  '125': set(['798 Sorella Court Suite 125']),
#  '146': set(['TX 146', 'Texas 146']),
#  '1464': set(['FM 1464']),
#  '1488': set(['FM 1488', 'Farm-to-Market Road 1488']),
#  '150': set(['Garth Road Suite 150']),
#  '160': set(['Nelson Way #160']),
#  '1663': set(['FM 1663']),
#  '1764': set(['Farm-to-Market Road 1764']),
#  '18': set(['800 W NASA Parkway #18']),
#  '180': set(['Katy Freeway #180']),
#  '185': set(['I-45 South, Suite 185']),
#  '1960': set(['FM 1960', 'Fm 1960']),
#  '200': set(['College Park Drive Ste 200']),
#  '2100': set(['FM 2100']),
#  '240': set(['Bissonnet St #240']),
#  '242': set(['SH 242']),
#  '249': set(['TX 249']),
#  '270': set(['FM 270']),
#  '290': set(['Highway 290', 'US 290', 'Windfern Rd #290']),
#  '2920': set(['FM 2920', 'Fm 2920']),
#  '300': set(['Town & Country Blvd #300']),
#  '332': set(['TX 332']),
#  '359': set(['FM 359', 'Fm 359']),
#  '36': set(['Highway 36', 'TX 36']),
#  '362': set(['FM 362']),
#  '45': set(['I 45']),
#  '502': set(['Northwest Freeway #502']),
#  '518': set(['FM 518', 'West FM 518']),
#  '529': set(['FM 529']),
#  '59': set(['Southwest Freeway 59', 'US 59', 'United States Highway 59']),
#  '6': set(['Highway 6',
#            'State Hwy 6',
#            'TX 6',
#            'Texas Highway 6',
#            'West Highway 6']),
#  '646': set(['FM 646']),
#  '6475': set(['County Rd 6475']),
#  '65': set(['County Rd 65']),
#  '650': set(['W Broadway, Suite 650']),
#  '704': set(['Memorial City Way #704']),
#  '77027': set(['77027']),
#  '77096': set(['Meyerland Plaza, Houston, TX 77096']),
#  '87': set(['Highway 87']),
#  '90': set(['Highway 90', 'US 90']),
#  '90A': set(['Highway 90A']),
#  '90a': set(['Hwy 90a']),
#  '925': set(['Katy Freeway Suite 925']),
#  '94': set(['County Road 94']),
#  '940': set(['St Joseph Pkwy #940']),
#  '9k': set(['I-45 #9k']),
#  'A': set(['Avenue A', 'Dickinson Avenue Suite A']),
#  'AVE': set(['Harris AVE']),
#  'AVENUE': set(['SSPRANGLETOP AVENUE']),
#  'Americas': set(['Avenida de Las Americas']),
#  'Ave': set(['Houston Ave',
#              'Lake Robbins Ave',
#              'N Houston Ave',
#              'Richmond Ave',
#              'S. Rice Ave',
#              'W Bellfort Ave',
#              'Washington Ave']),
#  'Ave.': set(['Bertner Ave.']),
#  'B': set(['Fry Road Suite B', 'Richmond Ave, Ste B']),
#  'Bailey': set(['Bailey']),
#  'Beechnut': set(['Beechnut']),
#  'Blossom': set(['Blossom']),
#  'Blvd': set(['Highland Blvd',
#               'John Freeman Blvd',
#               'Pasadena Blvd',
#               'Post Oak Blvd',
#               'Seawall Blvd',
#               'Sweetwater Blvd',
#               'University Blvd']),
#  'Blvd.': set(['Bellaire Blvd.', 'Central City Blvd.', 'Post Oak Blvd.']),
#  'Broadway': set(['Broadway']),
#  'Bypass': set(['Alvin Bypass', 'US 290 Bypass']),
#  'Caroline': set(['Caroline']),
#  'Circle': set(['Bonnard Circle',
#                 'Lansing Circle',
#                 'South Hidden View Circle',
#                 'West Town Center Circle']),
#  'Crossing': set(['Brazos Town Crossing', 'Woodland Field Crossing']),
#  'Crosstimbers': set(['West Crosstimbers']),
#  'Cypress': set(['Baker Cypress']),
#  'DRIVE': set(['STONEY CLOUD DRIVE']),
#  'Dallas': set(['W. Dallas']),
#  'Dr': set(['1111 Upland Dr',
#             'Business Center Dr',
#             'Kensington Dr',
#             'New Hampton Dr',
#             'Office Park Dr',
#             'Park Row Dr',
#             'Portway Dr',
#             'Post Oak Place Dr',
#             'S Wilcrest Dr',
#             'Six Pines Dr',
#             'Waugh Dr']),
#  'Driscoll': set(['Driscoll']),
#  'Durham': set(['Durham']),
#  'E': set(['Avenue E', 'FM 1960 E', 'N Sam Houston Pkwy E']),
#  'East': set(['FM 1960 East',
#               'North Sam Houston Parkway East',
#               'South Loop East']),
#  'Es': set(['Es']),
#  'F': set(['Avenue F', 'San Felipe Road, suite F', 'Winbern Street, Ste. F']),
#  'F463': set(['Memorial Drive Suite F463']),
#  'Felipe': set(['San Felipe']),
#  'Freeway': set(['East Freeway',
#                  'Eastex Freeway',
#                  'Gulf Freeway',
#                  'Katy Freeway',
#                  'North Freeway',
#                  'Northwest Freeway',
#                  'Southwest Freeway']),
#  'Frwy': set(['East Frwy']),
#  'Fuzzel': set(['Riley Fuzzel']),
#  'Fwy': set(['Katy Fwy', 'Northwest Fwy', 'Southwest Fwy']),
#  'Graustark': set(['Graustark']),
#  'Gulfcrest': set(['Gulfcrest']),
#  'Hidalgo': set(['Hidalgo']),
#  'Highway': set(['Palmer Highway', 'Spencer Highway']),
#  'Hillcroft': set(['Hillcroft']),
#  'I-45': set(['I-45']),
#  'Isle': set(['Morgan Isle']),
#  'Kempwood': set(['Kempwood']),
#  'Knolls': set(['Everett Knolls']),
#  'L': set(['Avenue L']),
#  'Lake': set(['Woodcreek Bend Lake']),
#  'Larchmont': set(['Larchmont']),
#  'Ln': set(['Iris Bay Ln']),
#  'Loop': set(['Taub Loop']),
#  'MacGregor': set(['South MacGregor']),
#  'Mall': set(['Baybrook Mall']),
#  'Maroneal': set(['Maroneal']),
#  'Mews': set(['Chesham Mews']),
#  'Montrose': set(['Montrose']),
#  'N': set(['Kingwood Drive #N',
#            'W Sam Houston Pky N',
#            'W Sam Houston Pwky N']),
#  'North': set(['21st Street North',
#                'East Sam Houston Parkway North',
#                'Grand Parkway North',
#                'Highway 59 North',
#                'Highway 6 North',
#                'Hwy 6 North',
#                'Interstate 45 North',
#                'Kings Manor Drive North',
#                'Raider Circle North',
#                'United States Highway 59 North',
#                'West Sam Houston Parkway North',
#                'Willow Place Drive North']),
#  'O': set(['Avenue O']),
#  'Oaks': set(['West Spreading Oaks']),
#  'Park': set(['Deer Park', 'NRG Park', 'Pin Oak Park']),
#  'Pkwy': set(['Shadow Creek Pkwy',
#               'Tomball Pkwy',
#               'West Lake Houston Pkwy',
#               'Will Clayton Pkwy']),
#  'Plaza': set(['Baylor Plaza', 'E Greenway Plaza', 'One Baylor Plaza']),
#  'Plaze': set(['One Baylor Plaze']),
#  'Q': set(['Avenue Q']),
#  'Rd': set(['Cypress North Houston Rd',
#             'E Atascocita Rd',
#             'E FM 528 Rd',
#             'Kuykendahl Rd',
#             'Old Katy Rd',
#             'Powerline Rd',
#             'Rogerdale Rd',
#             'Stuebner Airline Rd',
#             'Westheimer Rd']),
#  'Rd.': set(['1795 N Fry Rd.', 'W. Greens Rd.']),
#  'Real': set(['El Camino Real']),
#  'Richmond': set(['Richmond']),
#  'Ridge': set(['Creek Ridge']),
#  'Riverway': set(['Riverway']),
#  'Road)': set(['FM 1960 East (Humble-Huffman Road)']),
#  'Rock': set(['Chimney Rock']),
#  'Row': set(['Park Row']),
#  'S': set(['Avenue S', 'I-45 S', 'W Grand Pkwy S']),
#  'ST': set(['MONTGOMERY ST']),
#  'South': set(['E. Sam Houston Parkway South',
#                'West Grand Parkway South',
#                'West Loop South',
#                'West Sam Houston Parkway South',
#                'West Sam Houston Pkwy South']),
#  'Speedway': set(['Buffalo Speedway']),
#  'St': set([' W Clayton St',
#             'Beverlyhill St',
#             'Canal St',
#             'Dunlavy St',
#             'McCarty St',
#             'Milby St',
#             'N Delmar St',
#             'San Felipe St',
#             'Tuam St']),
#  'St.': set(['Dallas St.', 'East 13th St.']),
#  'Stree': set(['7th Stree']),
#  'T': set(['Avenue T']),
#  'T2008': set(['Southwest Freeway #T2008']),
#  'TX-332': set(['TX-332']),
#  'TX-6': set(['TX-6']),
#  'Terrace': set(['Skyview Terrace']),
#  'Texas': set(['BIRNHAM WOODS DRIVE SPRING, Texas']),
#  'Valley': set(['Pine Valley']),
#  'Walk': set(['City Walk']),
#  'Way': set(['By the Lake Way',
#              'Green Land Way',
#              'Homeward Way',
#              'Memorial City Way',
#              'Nelson Way',
#              'North MacGregor Way',
#              'This Way',
#              'Town and Country Way']),
#  'Welford': set(['Welford']),
#  'West': set(['1960 West',
#               'FM 1960 West',
#               'Hwy 290 West',
#               'North Loop West',
#               'South Loop West',
#               'South Sam Houston Parkway West']),
#  'Westheimer': set(['Westheimer']),
#  'Westhimer': set(['Westhimer']),
#  'blvd': set(['Highland blvd']),
#  'street': set(['32nd street', 'Washington street'])}

# %%
#process data and output json file

process_map(OSMFILE, False)
# Out:
# [{'created': {'changeset': '6369617',
#    'timestamp': '2010-11-14T18:44:21Z',
#    'uid': '9176',
#    'user': 'Maarten Deen',
#    'version': '2'},
#   'id': '4335942',
#   'pos': [29.353278, -95.487423],
#   'type': 'node'},
#  {'created': {'changeset': '6369617',
#    'timestamp': '2010-11-14T18:44:24Z',
#    'uid': '9176',
#    'user': 'Maarten Deen',
#    'version': '2'},
#   'id': '4421932',
#   'pos': [29.768133, -94.813628],
#   'type': 'node'},
#  {'created': {'changeset': '34502220',
#    'timestamp': '2015-10-08T00:49:18Z',
#    'uid': '220395',
#    'user': 'LizBarry',
#    'version': '15'},
#   'ele': '13',
#   'id': '27526178',
#   'is_in:continent': 'North America',
#   'is_in:country': 'United States',
#   'is_in:country_code': 'US',
#   'name': 'Houston',
#   'name:am': u'\u1202\u12cd\u1235\u1270\u1295',
#   'name:ar': u'\u0647\u064a\u0648\u0633\u062a\u0646\u060c \u062a\u0643\u0633\u0627\u0633',
#   'name:az': 'Hyuston',
#   'name:be': u"\u0425'\u044e\u0441\u0442\u0430\u043d",
#   'name:bg': u'\u0425\u044e\u0441\u0442\u044a\u043d',
#   'name:bn': u'\u09b9\u09bf\u0989\u09b8\u09cd\u099f\u09a8',
#   'name:ce': u'\u0425\u044c\u044e\u0441\u0442\u043e\u043d',
#   'name:el': u'\u03a7\u03b9\u03bf\u03cd\u03c3\u03c4\u03bf\u03bd',
#   'name:eo': 'Houston (Teksaso)',
#   'name:fa': u'\u0647\u06cc\u0648\u0633\u062a\u0648\u0646',
#   'name:gu': u'\u0ab9\u0acd\u0aaf\u0ac1\u0ab8\u0acd\u0a9f\u0aa8',
#   'name:he': u'\u05d9\u05d5\u05e1\u05d8\u05d5\u05df',
#   'name:hi': u'\u0939\u094d\u092f\u0941\u0938\u094d\u091f\u0928',
#   'name:hr': 'Houston, Teksas',
#   'name:hy': u'\u0540\u0575\u0578\u0582\u057d\u057f\u0578\u0576',
#   'name:ja': u'\u30d2\u30e5\u30fc\u30b9\u30c8\u30f3',
#   'name:ka': u'\u10f0\u10d8\u10e3\u10e1\u10e2\u10dd\u10dc\u10d8',
#   'name:kk': u'\u0425\u044c\u044e\u0441\u0442\u043e\u043d',
#   'name:kn': u'\u0cb9\u0ccd\u0caf\u0cc2\u0cb8\u0ccd\u0c9f\u0ca8\u0ccd',
#   'name:ko': u'\ud734\uc2a4\ud134',
#   'name:ku': 'Houston (Teksas)',
#   'name:kw': 'Houston, Teksas',
#   'name:la': 'Hustonia (Texia)',
#   'name:lt': 'Hiustonas',
#   'name:lv': u'Hj\u016bstona',
#   'name:mk': u'\u0425\u0458\u0443\u0441\u0442\u043e\u043d',
#   'name:ml': u'\u0d39\u0d4d\u0d2f\u0d42\u0d38\u0d4d\u0d31\u0d4d\u0d31\u0d7a (\u0d1f\u0d46\u0d15\u0d4d\u0d38\u0d38\u0d4d)',
#   'name:mr': u'\u0939\u094d\u092f\u0941\u0938\u094d\u091f\u0928',
#   'name:my': u'\u101f\u1030\u1005\u1010\u1014\u103a\u1019\u103c\u102d\u102f\u1037',
#   'name:ne': u'\u0939\u094d\u092f\u0941\u0938\u094d\u091f\u0928',
#   'name:os': u'\u0425\u044c\u044e\u0441\u0442\u043e\u043d',
#   'name:pa': u'\u0a39\u0a42\u0a38\u0a1f\u0a28',
#   'name:ru': u'\u0425\u044c\u044e\u0441\u0442\u043e\u043d',
#   'name:sl': 'Houston, Teksas',
#   'name:sr': u'\u0425\u0458\u0443\u0441\u0442\u043e\u043d',
#   'name:ta': u'\u0bb9\u0bbf\u0baf\u0bc2\u0bb8\u0bcd\u0b9f\u0ba9\u0bcd',
#   'name:te': u'\u0c39\u0c4d\u0c2f\u0c42\u0c38\u0c4d\u0c1f\u0c28\u0c4d',
#   'name:th': u'\u0e2e\u0e34\u0e27\u0e2a\u0e15\u0e31\u0e19',
#   'name:tl': 'Houston, Teksas',
#   'name:ug': 'Hyuston',
#   'name:uk': u"\u0425'\u044e\u0441\u0442\u043e\u043d",
#   'name:ur': u'\u06c1\u06cc\u0648\u0633\u0679\u0646',
#   'name:uz': 'Hyuston',
#   'name:yi': u'\u05d4\u05d9\u05d5\u05e1\u05d8\u05df',
#   'name:zh': u'\u4f11\u65af\u6566',
#   'place': 'city',
#   'population': '2100263',
#   'population:date': '2010',
#   'population:source': 'US Census 2010',
#   'pos': [29.7589382, -95.3676974],
#   'type': 'node',
#   'wikipedia': 'en:Houston'},
#  {'created': {'changeset': '10938990',
#    'timestamp': '2012-03-11T04:38:58Z',
#    'uid': '239998',
#    'user': 'Sundance',
#    'version': '15'},
#   'id': '35053736',
#   'pos': [29.2884754, -94.8385579],
#   'type': 'node'},
#  {'created': {'changeset': '10938990',
#    'timestamp': '2012-03-11T04:38:58Z',
#    'uid': '239998',
#    'user': 'Sundance',
#    'version': '3'},
#   'id': '35053737',
#   'pos': [29.288497, -94.8373599],
#   'type': 'node'},
#  {'created': {'changeset': '10938990',
#    'timestamp': '2012-03-11T04:38:58Z',
#    'uid': '239998',
#    'user': 'Sundance',
#    'version': '2'},
#   'id': '35053738',
#   'pos': [29.2885407, -94.8362794],
#   'type': 'node'},
#  {'created': {'changeset': '10938990',
#    'timestamp': '2012-03-11T04:38:58Z',
#    'uid': '239998',
#    'user': 'Sundance',
#    'version': '5'},
#   'id': '35053739',
#   'pos': [29.2887367, -94.8349278],
#   'type': 'node'},
#  {'created': {'changeset': '13289030',
#    'timestamp': '2012-09-28T19:14:34Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '3'},
#   'id': '54347568',
#   'pos': [29.2923764, -94.7956866],
#   'type': 'node'},
#  {'created': {'changeset': '9214891',
#    'timestamp': '2011-09-05T07:10:21Z',
#    'uid': '119881',
#    'user': 'claysmalley',
#    'version': '6'},
#   'id': '54365022',
#   'pos': [29.3046631, -94.7724706],
#   'type': 'node'},
#  {'created': {'changeset': '468560',
#    'timestamp': '2007-09-19T05:02:32Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'id': '54379213',
#   'pos': [29.1826227, -94.9688111],
#   'type': 'node'},
#  {'created': {'changeset': '468560',
#    'timestamp': '2007-09-19T05:02:32Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'id': '54379215',
#   'pos': [29.2006807, -94.9834882],
#   'type': 'node'},
#  {'created': {'changeset': '468560',
#    'timestamp': '2007-09-19T05:02:32Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'id': '54379216',
#   'pos': [29.2005308, -94.9916421],
#   'type': 'node'},
#  {'created': {'changeset': '468560',
#    'timestamp': '2007-09-19T05:02:32Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'id': '54379218',
#   'pos': [29.1995568, -94.9917279],
#   'type': 'node'},
#  {'created': {'changeset': '36713117',
#    'timestamp': '2016-01-21T03:43:59Z',
#    'uid': '3269109',
#    'user': 'clarceneaux',
#    'version': '2'},
#   'id': '54379219',
#   'pos': [29.1809, -94.976228],
#   'type': 'node'},
#  {'created': {'changeset': '36713117',
#    'timestamp': '2016-01-21T03:43:59Z',
#    'uid': '3269109',
#    'user': 'clarceneaux',
#    'version': '2'},
#   'id': '54379220',
#   'pos': [29.1792425, -94.9789748],
#   'type': 'node'},
#  {'created': {'changeset': '36713117',
#    'timestamp': '2016-01-21T03:43:59Z',
#    'uid': '3269109',
#    'user': 'clarceneaux',
#    'version': '2'},
#   'id': '54379222',
#   'pos': [29.1773967, -94.977508],
#   'type': 'node'},
#  {'created': {'changeset': '13322277',
#    'timestamp': '2012-10-01T13:22:18Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '2'},
#   'id': '54597586',
#   'pos': [29.2728153, -94.870815],
#   'type': 'node'},
#  {'created': {'changeset': '13322277',
#    'timestamp': '2012-10-01T13:22:18Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '2'},
#   'id': '54597588',
#   'pos': [29.2722346, -94.8720377],
#   'type': 'node'},
#  {'created': {'changeset': '13322277',
#    'timestamp': '2012-10-01T13:22:18Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '2'},
#   'id': '54597589',
#   'pos': [29.2703045, -94.8711878],
#   'type': 'node'},
#  {'created': {'changeset': '13322277',
#    'timestamp': '2012-10-01T13:22:18Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '2'},
#   'id': '54597590',
#   'pos': [29.2700914, -94.86934],
#   'type': 'node'},
#  {'created': {'changeset': '13322277',
#    'timestamp': '2012-10-01T13:22:18Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '2'},
#   'id': '54597593',
#   'pos': [29.2683625, -94.8672892],
#   'type': 'node'},
#  {'created': {'changeset': '13322277',
#    'timestamp': '2012-10-01T13:22:18Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '2'},
#   'id': '54597596',
#   'pos': [29.2676781, -94.8656925],
#   'type': 'node'},
#  {'created': {'changeset': '13322277',
#    'timestamp': '2012-10-01T13:22:18Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '2'},
#   'id': '54597598',
#   'pos': [29.2622898, -94.8605241],
#   'type': 'node'},
#  {'created': {'changeset': '13322277',
#    'timestamp': '2012-10-01T13:22:18Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '2'},
#   'id': '54597602',
#   'pos': [29.2531855, -94.8615337],
#   'type': 'node'},
#  {'created': {'changeset': '13322277',
#    'timestamp': '2012-10-01T13:22:18Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '2'},
#   'id': '54597604',
#   'pos': [29.2533861, -94.8576769],
#   'type': 'node'},
#  {'created': {'changeset': '472935',
#    'timestamp': '2007-09-19T11:56:30Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'id': '54597605',
#   'pos': [29.2561836, -94.8504077],
#   'type': 'node'},
#  {'created': {'changeset': '13322277',
#    'timestamp': '2012-10-01T13:22:18Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '2'},
#   'id': '54597606',
#   'pos': [29.2603872, -94.8525147],
#   'type': 'node'},
#  {'created': {'changeset': '30048799',
#    'timestamp': '2015-04-07T20:11:59Z',
#    'uid': '42429',
#    'user': '42429',
#    'version': '3'},
#   'id': '54597607',
#   'pos': [29.2599644, -94.8535792],
#   'power': 'pole',
#   'type': 'node'},
#  {'created': {'changeset': '30046411',
#    'timestamp': '2015-04-07T18:21:40Z',
#    'uid': '42429',
#    'user': '42429',
#    'version': '3'},
#   'id': '54597608',
#   'pos': [29.2609448, -94.8540951],
#   'type': 'node'},
#  {'created': {'changeset': '30046411',
#    'timestamp': '2015-04-07T18:21:40Z',
#    'uid': '42429',
#    'user': '42429',
#    'version': '3'},
#   'id': '54597610',
#   'pos': [29.2612884, -94.853237],
#   'type': 'node'},
#  {'created': {'changeset': '13322277',
#    'timestamp': '2012-10-01T13:22:18Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '2'},
#   'id': '54597612',
#   'pos': [29.2625311, -94.8536778],
#   'type': 'node'},
#  {'created': {'changeset': '13322277',
#    'timestamp': '2012-10-01T13:22:18Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '2'},
#   'id': '54597614',
#   'pos': [29.2616187, -94.8549309],
#   'type': 'node'},
#  {'created': {'changeset': '13322277',
#    'timestamp': '2012-10-01T13:22:18Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '2'},
#   'id': '54597615',
#   'pos': [29.2691104, -94.8546879],
#   'type': 'node'},
#  {'created': {'changeset': '13322277',
#    'timestamp': '2012-10-01T13:22:18Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '2'},
#   'id': '54597617',
#   'pos': [29.2699276, -94.852717],
#   'type': 'node'},
#  {'created': {'changeset': '13322277',
#    'timestamp': '2012-10-01T13:22:18Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '2'},
#   'id': '54597622',
#   'pos': [29.2776296, -94.8570819],
#   'type': 'node'},
#  {'created': {'changeset': '27595012',
#    'timestamp': '2014-12-20T19:06:17Z',
#    'uid': '94578',
#    'user': 'andygol',
#    'version': '5'},
#   'id': '54611749',
#   'is_in': 'Texas',
#   'name': 'Galveston',
#   'name:en': 'Galveston',
#   'name:ru': u'\u0413\u0430\u043b\u0432\u0435\u0441\u0442\u043e\u043d',
#   'name:uk': u'\u0490\u0430\u043b\u0432\u0435\u0441\u0442\u043e\u043d',
#   'place': 'town',
#   'population': '47743',
#   'pos': [29.299328, -94.7945882],
#   'type': 'node',
#   'wikidata': 'Q135744'},
#  {'created': {'changeset': '245696',
#    'timestamp': '2007-10-18T23:55:49Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '4'},
#   'created_by': 'Potlatch 0.4a',
#   'id': '54619402',
#   'name': 'Jamaica Beach',
#   'place': 'village',
#   'pos': [29.1831247, -94.9729396],
#   'type': 'node'},
#  {'created': {'changeset': '13853958',
#    'timestamp': '2012-11-12T23:46:13Z',
#    'uid': '24247',
#    'user': 'Vlad',
#    'version': '2'},
#   'id': '54626185',
#   'pos': [29.1139905, -95.0809326],
#   'type': 'node'},
#  {'created': {'changeset': '25081720',
#    'timestamp': '2014-08-28T19:38:49Z',
#    'uid': '167417',
#    'user': 'osm-sputnik',
#    'version': '3'},
#   'id': '54626186',
#   'pos': [29.1135769, -95.0815318],
#   'type': 'node'},
#  {'created': {'changeset': '25081720',
#    'timestamp': '2014-08-28T19:38:49Z',
#    'uid': '167417',
#    'user': 'osm-sputnik',
#    'version': '3'},
#   'id': '54627818',
#   'pos': [29.1134616, -95.0817402],
#   'type': 'node'},
#  {'created': {'changeset': '25081720',
#    'timestamp': '2014-08-28T19:38:49Z',
#    'uid': '167417',
#    'user': 'osm-sputnik',
#    'version': '3'},
#   'id': '54627819',
#   'pos': [29.1133247, -95.0819948],
#   'type': 'node'},
#  {'created': {'changeset': '25081720',
#    'timestamp': '2014-08-28T19:38:49Z',
#    'uid': '167417',
#    'user': 'osm-sputnik',
#    'version': '2'},
#   'id': '54627820',
#   'pos': [29.1131424, -95.0824112],
#   'type': 'node'},
#  {'created': {'changeset': '25081720',
#    'timestamp': '2014-08-28T19:38:49Z',
#    'uid': '167417',
#    'user': 'osm-sputnik',
#    'version': '3'},
#   'id': '54627822',
#   'pos': [29.1130072, -95.0828271],
#   'type': 'node'},
#  {'created': {'changeset': '25081720',
#    'timestamp': '2014-08-28T19:38:49Z',
#    'uid': '167417',
#    'user': 'osm-sputnik',
#    'version': '3'},
#   'id': '54627823',
#   'pos': [29.1128951, -95.0832941],
#   'type': 'node'},
#  {'created': {'changeset': '25081720',
#    'timestamp': '2014-08-28T19:38:49Z',
#    'uid': '167417',
#    'user': 'osm-sputnik',
#    'version': '3'},
#   'id': '54627824',
#   'pos': [29.1128265, -95.0837245],
#   'type': 'node'},
#  {'created': {'changeset': '25081720',
#    'timestamp': '2014-08-28T19:38:49Z',
#    'uid': '167417',
#    'user': 'osm-sputnik',
#    'version': '2'},
#   'id': '54627825',
#   'pos': [29.1127959, -95.0846445],
#   'type': 'node'},
#  {'created': {'changeset': '25081720',
#    'timestamp': '2014-08-28T19:38:49Z',
#    'uid': '167417',
#    'user': 'osm-sputnik',
#    'version': '2'},
#   'id': '54627826',
#   'pos': [29.1128169, -95.0849504],
#   'type': 'node'},
#  {'created': {'changeset': '25081720',
#    'timestamp': '2014-08-28T19:38:49Z',
#    'uid': '167417',
#    'user': 'osm-sputnik',
#    'version': '2'},
#   'id': '54627827',
#   'pos': [29.1128558, -95.0853348],
#   'type': 'node'},
#  {'created': {'changeset': '25081720',
#    'timestamp': '2014-08-28T19:38:49Z',
#    'uid': '167417',
#    'user': 'osm-sputnik',
#    'version': '2'},
#   'id': '54627828',
#   'pos': [29.112907, -95.0859001],
#   'type': 'node'},
#  {'created': {'changeset': '25081720',
#    'timestamp': '2014-08-28T19:38:49Z',
#    'uid': '167417',
#    'user': 'osm-sputnik',
#    'version': '2'},
#   'id': '54627829',
#   'pos': [29.1129069, -95.0866697],
#   'type': 'node'},
#  {'created': {'changeset': '25081720',
#    'timestamp': '2014-08-28T19:38:49Z',
#    'uid': '167417',
#    'user': 'osm-sputnik',
#    'version': '2'},
#   'id': '54627830',
#   'pos': [29.1128559, -95.0870894],
#   'type': 'node'},
#  {'created': {'changeset': '472935',
#    'timestamp': '2007-09-19T13:10:31Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'id': '54627831',
#   'pos': [29.1127359, -95.0877724],
#   'type': 'node'},
#  {'created': {'changeset': '472935',
#    'timestamp': '2007-09-19T13:10:31Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'id': '54627832',
#   'pos': [29.1125034, -95.0883389],
#   'type': 'node'},
#  {'created': {'changeset': '472935',
#    'timestamp': '2007-09-19T13:10:31Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'id': '54627833',
#   'pos': [29.112271, -95.0888281],
#   'type': 'node'},
#  {'created': {'changeset': '472935',
#    'timestamp': '2007-09-19T13:10:25Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'id': '54627834',
#   'pos': [29.111791, -95.0895749],
#   'type': 'node'},
#  {'created': {'changeset': '472935',
#    'timestamp': '2007-09-19T13:10:31Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'id': '54627835',
#   'pos': [29.1112661, -95.0901757],
#   'type': 'node'},
#  {'created': {'changeset': '472935',
#    'timestamp': '2007-09-19T13:10:31Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'id': '54627836',
#   'pos': [29.1105912, -95.0907765],
#   'type': 'node'},
#  {'created': {'changeset': '472935',
#    'timestamp': '2007-09-19T13:10:31Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'id': '54627837',
#   'pos': [29.1099538, -95.0914031],
#   'type': 'node'},
#  {'created': {'changeset': '22053225',
#    'timestamp': '2014-04-30T22:06:39Z',
#    'uid': '1110270',
#    'user': 'afdreher',
#    'version': '2'},
#   'id': '54627838',
#   'pos': [29.1095031, -95.0919308],
#   'type': 'node'},
#  {'created': {'changeset': '22053225',
#    'timestamp': '2014-04-30T22:06:39Z',
#    'uid': '1110270',
#    'user': 'afdreher',
#    'version': '2'},
#   'id': '54627840',
#   'pos': [29.109011, -95.0926174],
#   'type': 'node'},
#  {'created': {'changeset': '22053225',
#    'timestamp': '2014-04-30T22:06:39Z',
#    'uid': '1110270',
#    'user': 'afdreher',
#    'version': '2'},
#   'id': '54627841',
#   'pos': [29.1088188, -95.0929339],
#   'type': 'node'},
#  {'created': {'changeset': '22053225',
#    'timestamp': '2014-04-30T22:06:39Z',
#    'uid': '1110270',
#    'user': 'afdreher',
#    'version': '2'},
#   'id': '54627842',
#   'pos': [29.1082845, -95.0939424],
#   'type': 'node'},
#  {'created': {'changeset': '22053225',
#    'timestamp': '2014-04-30T22:06:39Z',
#    'uid': '1110270',
#    'user': 'afdreher',
#    'version': '2'},
#   'id': '54627843',
#   'pos': [29.1079119, -95.0945567],
#   'type': 'node'},
#  {'created': {'changeset': '22053225',
#    'timestamp': '2014-04-30T22:06:39Z',
#    'uid': '1110270',
#    'user': 'afdreher',
#    'version': '2'},
#   'id': '54627844',
#   'pos': [29.1076658, -95.0949],
#   'type': 'node'},
#  {'created': {'changeset': '22053290',
#    'timestamp': '2014-04-30T22:10:50Z',
#    'uid': '1110270',
#    'user': 'afdreher',
#    'version': '2'},
#   'id': '54627846',
#   'pos': [29.1062644, -95.0962867],
#   'type': 'node'},
#  {'created': {'changeset': '22053290',
#    'timestamp': '2014-04-30T22:10:50Z',
#    'uid': '1110270',
#    'user': 'afdreher',
#    'version': '2'},
#   'id': '54627847',
#   'pos': [29.10532, -95.0970538],
#   'type': 'node'},
#  {'created': {'changeset': '22052096',
#    'timestamp': '2014-04-30T21:03:36Z',
#    'uid': '1110270',
#    'user': 'afdreher',
#    'version': '2'},
#   'id': '54627849',
#   'pos': [29.1040053, -95.0982444],
#   'type': 'node'},
#  {'created': {'changeset': '22052096',
#    'timestamp': '2014-04-30T21:03:36Z',
#    'uid': '1110270',
#    'user': 'afdreher',
#    'version': '2'},
#   'id': '54627850',
#   'pos': [29.1035858, -95.0987272],
#   'type': 'node'},
#  {'created': {'changeset': '22052096',
#    'timestamp': '2014-04-30T21:03:36Z',
#    'uid': '1110270',
#    'user': 'afdreher',
#    'version': '2'},
#   'id': '54627851',
#   'pos': [29.1031809, -95.0992747],
#   'type': 'node'},
#  {'created': {'changeset': '22052096',
#    'timestamp': '2014-04-30T21:03:36Z',
#    'uid': '1110270',
#    'user': 'afdreher',
#    'version': '2'},
#   'id': '54627852',
#   'pos': [29.1028481, -95.0997682],
#   'type': 'node'},
#  {'created': {'changeset': '22052096',
#    'timestamp': '2014-04-30T21:03:36Z',
#    'uid': '1110270',
#    'user': 'afdreher',
#    'version': '2'},
#   'id': '54627853',
#   'pos': [29.1024755, -95.1004468],
#   'type': 'node'},
#  {'created': {'changeset': '22052096',
#    'timestamp': '2014-04-30T21:03:36Z',
#    'uid': '1110270',
#    'user': 'afdreher',
#    'version': '2'},
#   'id': '54627854',
#   'pos': [29.1022212, -95.1009966],
#   'type': 'node'},
#  {'created': {'changeset': '22052096',
#    'timestamp': '2014-04-30T21:03:36Z',
#    'uid': '1110270',
#    'user': 'afdreher',
#    'version': '2'},
#   'id': '54627855',
#   'pos': [29.1018568, -95.1018482],
#   'type': 'node'},
#  {'created': {'changeset': '22052096',
#    'timestamp': '2014-04-30T21:03:36Z',
#    'uid': '1110270',
#    'user': 'afdreher',
#    'version': '2'},
#   'id': '54627856',
#   'pos': [29.1015369, -95.1025738],
#   'type': 'node'},
#  {'created': {'changeset': '22052096',
#    'timestamp': '2014-04-30T21:03:36Z',
#    'uid': '1110270',
#    'user': 'afdreher',
#    'version': '2'},
#   'id': '54627858',
#   'pos': [29.1013822, -95.1028715],
#   'type': 'node'},
#  {'created': {'changeset': '22052096',
#    'timestamp': '2014-04-30T21:03:36Z',
#    'uid': '1110270',
#    'user': 'afdreher',
#    'version': '2'},
#   'id': '54627859',
#   'pos': [29.1011397, -95.103302],
#   'type': 'node'},
#  {'created': {'changeset': '14132216',
#    'timestamp': '2012-12-02T22:21:13Z',
#    'uid': '8703',
#    'user': 'rolandg',
#    'version': '3'},
#   'id': '54627860',
#   'pos': [29.1007365, -95.1038991],
#   'type': 'node'},
#  {'created': {'changeset': '22053290',
#    'timestamp': '2014-04-30T22:10:50Z',
#    'uid': '1110270',
#    'user': 'afdreher',
#    'version': '3'},
#   'id': '54627861',
#   'pos': [29.1004899, -95.1042502],
#   'type': 'node'},
#  {'created': {'changeset': '9457050',
#    'timestamp': '2011-10-03T06:24:15Z',
#    'uid': '37392',
#    'user': '25or6to4',
#    'version': '2'},
#   'id': '54627862',
#   'pos': [29.0998021, -95.1050188],
#   'type': 'node'},
#  {'created': {'changeset': '22051873',
#    'timestamp': '2014-04-30T20:51:06Z',
#    'uid': '1110270',
#    'user': 'afdreher',
#    'version': '3'},
#   'id': '54627864',
#   'pos': [29.0988318, -95.1058654],
#   'type': 'node'},
#  {'created': {'changeset': '9457050',
#    'timestamp': '2011-10-03T06:24:15Z',
#    'uid': '37392',
#    'user': '25or6to4',
#    'version': '2'},
#   'id': '54627865',
#   'pos': [29.0984216, -95.1061515],
#   'type': 'node'},
#  {'created': {'changeset': '22051873',
#    'timestamp': '2014-04-30T20:51:06Z',
#    'uid': '1110270',
#    'user': 'afdreher',
#    'version': '3'},
#   'id': '54627866',
#   'pos': [29.0978029, -95.1064997],
#   'type': 'node'},
#  {'created': {'changeset': '9457050',
#    'timestamp': '2011-10-03T06:24:15Z',
#    'uid': '37392',
#    'user': '25or6to4',
#    'version': '2'},
#   'id': '54627867',
#   'pos': [29.0971984, -95.1067958],
#   'type': 'node'},
#  {'created': {'changeset': '9457050',
#    'timestamp': '2011-10-03T06:24:16Z',
#    'uid': '37392',
#    'user': '25or6to4',
#    'version': '2'},
#   'id': '54627868',
#   'pos': [29.0965449, -95.1071007],
#   'type': 'node'},
#  {'created': {'changeset': '22053290',
#    'timestamp': '2014-04-30T22:10:50Z',
#    'uid': '1110270',
#    'user': 'afdreher',
#    'version': '3'},
#   'id': '54627869',
#   'pos': [29.0959924, -95.1073669],
#   'type': 'node'},
#  {'created': {'changeset': '22053290',
#    'timestamp': '2014-04-30T22:10:50Z',
#    'uid': '1110270',
#    'user': 'afdreher',
#    'version': '3'},
#   'id': '54627870',
#   'pos': [29.0954392, -95.1076995],
#   'type': 'node'},
#  {'created': {'changeset': '22053290',
#    'timestamp': '2014-04-30T22:10:50Z',
#    'uid': '1110270',
#    'user': 'afdreher',
#    'version': '3'},
#   'id': '54627871',
#   'pos': [29.0950596, -95.1080106],
#   'type': 'node'},
#  {'created': {'changeset': '22053290',
#    'timestamp': '2014-04-30T22:10:50Z',
#    'uid': '1110270',
#    'user': 'afdreher',
#    'version': '3'},
#   'id': '54627872',
#   'pos': [29.0948041, -95.1082574],
#   'type': 'node'},
#  {'created': {'changeset': '22053290',
#    'timestamp': '2014-04-30T22:10:50Z',
#    'uid': '1110270',
#    'user': 'afdreher',
#    'version': '3'},
#   'id': '54627873',
#   'pos': [29.0944478, -95.1086758],
#   'type': 'node'},
#  {'barrier': 'toll_booth',
#   'created': {'changeset': '11611007',
#    'timestamp': '2012-05-16T05:51:42Z',
#    'uid': '207745',
#    'user': 'NE2',
#    'version': '3'},
#   'fee': '$2',
#   'id': '54629035',
#   'pos': [29.0921128, -95.1116727],
#   'type': 'node'},
#  {'created': {'changeset': '473457',
#    'timestamp': '2007-09-20T02:37:47Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'id': '54903356',
#   'pos': [29.0939124, -95.1094447],
#   'type': 'node'},
#  {'created': {'changeset': '473457',
#    'timestamp': '2007-09-20T02:37:47Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'id': '54903358',
#   'pos': [29.0931848, -95.1104318],
#   'type': 'node'},
#  {'created': {'changeset': '473457',
#    'timestamp': '2007-09-20T02:37:47Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'id': '54903359',
#   'pos': [29.0925848, -95.1111785],
#   'type': 'node'},
#  {'created': {'changeset': '11611007',
#    'timestamp': '2012-05-16T05:51:42Z',
#    'uid': '207745',
#    'user': 'NE2',
#    'version': '2'},
#   'id': '54903361',
#   'pos': [29.092233, -95.11155],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:38:14Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453356',
#   'pos': [29.3164686, -94.795004],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:38:14Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453359',
#   'pos': [29.3141785, -94.793562],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:05:23Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453361',
#   'pos': [29.3147517, -94.7922655],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:05:23Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453368',
#   'pos': [29.3157964, -94.7905351],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:05:24Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453376',
#   'pos': [29.3172923, -94.7886118],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:05:25Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453379',
#   'pos': [29.317506, -94.7881132],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:38:14Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453383',
#   'pos': [29.3188859, -94.7868415],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:38:14Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453387',
#   'pos': [29.3193199, -94.7858973],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:38:14Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453391',
#   'pos': [29.3194247, -94.7859746],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:38:14Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453394',
#   'pos': [29.3200907, -94.7870646],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:38:14Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453401',
#   'pos': [29.3205023, -94.7867042],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:38:14Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453410',
#   'pos': [29.320188, -94.7861548],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:38:14Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453416',
#   'pos': [29.3196866, -94.7853223],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:38:14Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453419',
#   'pos': [29.3203377, -94.7846442],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:38:14Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453433',
#   'pos': [29.3207792, -94.7853051],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:38:14Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453436',
#   'pos': [29.3212656, -94.7849446],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:38:14Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453441',
#   'pos': [29.320854, -94.784258],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:38:14Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453444',
#   'pos': [29.3215275, -94.783743],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:38:14Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453448',
#   'pos': [29.3222534, -94.7849446],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:38:14Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453452',
#   'pos': [29.3224854, -94.784773],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:38:14Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453458',
#   'pos': [29.322695, -94.7846099],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:05:39Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453470',
#   'pos': [29.3223499, -94.7840529],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:38:14Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453473',
#   'pos': [29.3219391, -94.7833568],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:38:14Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453475',
#   'pos': [29.3221337, -94.7831078],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:38:14Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453477',
#   'pos': [29.322448, -94.783228],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:38:14Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453484',
#   'pos': [29.3228222, -94.7828675],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:38:14Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453486',
#   'pos': [29.3236079, -94.7839404],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:38:14Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453494',
#   'pos': [29.3241168, -94.7834512],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:38:14Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453497',
#   'pos': [29.3237202, -94.7829362],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:38:14Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453500',
#   'pos': [29.3233385, -94.7823697],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:05:44Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453504',
#   'pos': [29.3235089, -94.7821174],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:05:44Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453508',
#   'pos': [29.3237226, -94.7819037],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:05:45Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453510',
#   'pos': [29.3239007, -94.7815119],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:38:14Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453514',
#   'pos': [29.3240719, -94.7814084],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:38:14Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453517',
#   'pos': [29.3246481, -94.7815371],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:05:46Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453526',
#   'pos': [29.3250761, -94.7816543],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:38:14Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453530',
#   'pos': [29.3254563, -94.7817002],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:38:14Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453536',
#   'pos': [29.3259277, -94.7817775],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:38:14Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453543',
#   'pos': [29.3264815, -94.7817517],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:38:14Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453550',
#   'pos': [29.3269379, -94.7817517],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:38:14Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453557',
#   'pos': [29.3273196, -94.7817088],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:05:50Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453564',
#   'pos': [29.3275336, -94.7816187],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:05:50Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453569',
#   'pos': [29.327961, -94.7816187],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:05:50Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453574',
#   'pos': [29.3282103, -94.7814763],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:38:14Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453577',
#   'pos': [29.3285543, -94.7814942],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:38:14Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453579',
#   'pos': [29.328891, -94.7815371],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:38:14Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453582',
#   'pos': [29.3292277, -94.7815715],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:05:53Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453586',
#   'pos': [29.3295281, -94.7815475],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:05:54Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453590',
#   'pos': [29.3299912, -94.7814763],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:05:55Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453592',
#   'pos': [29.3305966, -94.7814763],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:05:57Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453594',
#   'pos': [29.3309172, -94.7815119],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:05:58Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453597',
#   'pos': [29.331309, -94.7812982],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:05:58Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453598',
#   'pos': [29.331772, -94.7811913],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:05:59Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453602',
#   'pos': [29.3322706, -94.7809776],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:06:00Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453607',
#   'pos': [29.3324843, -94.7806927],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:06:00Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453610',
#   'pos': [29.3330186, -94.7805859],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:06:01Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453612',
#   'pos': [29.3334103, -94.7804078],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:06:01Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453613',
#   'pos': [29.3338021, -94.7801941],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:06:02Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453615',
#   'pos': [29.3339446, -94.7799448],
#   'type': 'node'},
#  {'created': {'changeset': '5051907',
#    'timestamp': '2010-06-22T15:09:10Z',
#    'uid': '196098',
#    'user': 'xsintrik',
#    'version': '2'},
#   'id': '55453617',
#   'pos': [29.3339157, -94.7794622],
#   'type': 'node'},
#  {'created': {'changeset': '5051907',
#    'timestamp': '2010-06-22T15:09:10Z',
#    'uid': '196098',
#    'user': 'xsintrik',
#    'version': '2'},
#   'id': '55453618',
#   'pos': [29.3338502, -94.7791296],
#   'type': 'node'},
#  {'created': {'changeset': '5051907',
#    'timestamp': '2010-06-22T15:09:10Z',
#    'uid': '196098',
#    'user': 'xsintrik',
#    'version': '2'},
#   'id': '55453619',
#   'pos': [29.333925, -94.7788453],
#   'type': 'node'},
#  {'created': {'changeset': '5051907',
#    'timestamp': '2010-06-22T15:09:10Z',
#    'uid': '196098',
#    'user': 'xsintrik',
#    'version': '2'},
#   'id': '55453621',
#   'pos': [29.33378, -94.7782391],
#   'type': 'node'},
#  {'created': {'changeset': '5051907',
#    'timestamp': '2010-06-22T15:09:10Z',
#    'uid': '196098',
#    'user': 'xsintrik',
#    'version': '2'},
#   'id': '55453625',
#   'pos': [29.3338923, -94.7781747],
#   'type': 'node'},
#  {'created': {'changeset': '5051907',
#    'timestamp': '2010-06-22T15:09:10Z',
#    'uid': '196098',
#    'user': 'xsintrik',
#    'version': '2'},
#   'id': '55453627',
#   'pos': [29.3340513, -94.7781318],
#   'type': 'node'},
#  {'created': {'changeset': '5051907',
#    'timestamp': '2010-06-22T15:09:10Z',
#    'uid': '196098',
#    'user': 'xsintrik',
#    'version': '2'},
#   'id': '55453629',
#   'pos': [29.3344628, -94.7779977],
#   'type': 'node'},
#  {'created': {'changeset': '5051907',
#    'timestamp': '2010-06-22T15:09:09Z',
#    'uid': '196098',
#    'user': 'xsintrik',
#    'version': '2'},
#   'id': '55453631',
#   'pos': [29.3347341, -94.7779065],
#   'type': 'node'},
#  {'created': {'changeset': '5051907',
#    'timestamp': '2010-06-22T15:09:09Z',
#    'uid': '196098',
#    'user': 'xsintrik',
#    'version': '2'},
#   'id': '55453634',
#   'pos': [29.3349726, -94.7778099],
#   'type': 'node'},
#  {'created': {'changeset': '5051907',
#    'timestamp': '2010-06-22T15:09:09Z',
#    'uid': '196098',
#    'user': 'xsintrik',
#    'version': '2'},
#   'id': '55453636',
#   'pos': [29.3351549, -94.7777563],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:06:09Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453640',
#   'pos': [29.3353692, -94.7776653],
#   'type': 'node'},
#  {'created': {'changeset': '5051907',
#    'timestamp': '2010-06-22T15:09:09Z',
#    'uid': '196098',
#    'user': 'xsintrik',
#    'version': '2'},
#   'id': '55453644',
#   'pos': [29.3356226, -94.7775685],
#   'type': 'node'},
#  {'created': {'changeset': '5051907',
#    'timestamp': '2010-06-22T15:09:09Z',
#    'uid': '196098',
#    'user': 'xsintrik',
#    'version': '2'},
#   'id': '55453646',
#   'pos': [29.335805, -94.7772681],
#   'type': 'node'},
#  {'created': {'changeset': '5051907',
#    'timestamp': '2010-06-22T15:09:09Z',
#    'uid': '196098',
#    'user': 'xsintrik',
#    'version': '2'},
#   'id': '55453650',
#   'pos': [29.3362118, -94.7770804],
#   'type': 'node'},
#  {'created': {'changeset': '5051907',
#    'timestamp': '2010-06-22T15:09:09Z',
#    'uid': '196098',
#    'user': 'xsintrik',
#    'version': '2'},
#   'id': '55453654',
#   'pos': [29.3365158, -94.7769892],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:06:12Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453659',
#   'pos': [29.3371857, -94.7767393],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:38:14Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453664',
#   'pos': [29.337279, -94.7769023],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:06:13Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453668',
#   'pos': [29.3373638, -94.7772735],
#   'type': 'node'},
#  {'created': {'changeset': '42335872',
#    'timestamp': '2016-09-22T00:01:50Z',
#    'uid': '4559454',
#    'user': 'Achillespotter',
#    'version': '3'},
#   'id': '55453674',
#   'pos': [29.3382898, -94.778019],
#   'type': 'node'},
#  {'created': {'changeset': '5051907',
#    'timestamp': '2010-06-22T15:09:08Z',
#    'uid': '196098',
#    'user': 'xsintrik',
#    'version': '2'},
#   'id': '55453680',
#   'pos': [29.3373716, -94.7777563],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:06:14Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453689',
#   'pos': [29.3369364, -94.7779146],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:06:14Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453693',
#   'pos': [29.3365802, -94.7780927],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:06:15Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453696',
#   'pos': [29.3361172, -94.7783064],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:06:16Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453699',
#   'pos': [29.3358679, -94.7784845],
#   'type': 'node'},
#  {'created': {'changeset': '5051907',
#    'timestamp': '2010-06-22T15:09:08Z',
#    'uid': '196098',
#    'user': 'xsintrik',
#    'version': '2'},
#   'id': '55453700',
#   'pos': [29.3356974, -94.778738],
#   'type': 'node'},
#  {'created': {'changeset': '5051907',
#    'timestamp': '2010-06-22T15:09:07Z',
#    'uid': '196098',
#    'user': 'xsintrik',
#    'version': '2'},
#   'id': '55453703',
#   'pos': [29.3352298, -94.7793173],
#   'type': 'node'},
#  {'created': {'changeset': '5051907',
#    'timestamp': '2010-06-22T15:09:07Z',
#    'uid': '196098',
#    'user': 'xsintrik',
#    'version': '2'},
#   'id': '55453705',
#   'pos': [29.3350801, -94.7795104],
#   'type': 'node'},
#  {'created': {'changeset': '5051907',
#    'timestamp': '2010-06-22T15:09:07Z',
#    'uid': '196098',
#    'user': 'xsintrik',
#    'version': '2'},
#   'id': '55453708',
#   'pos': [29.3350287, -94.7798001],
#   'type': 'node'},
#  {'created': {'changeset': '5051907',
#    'timestamp': '2010-06-22T15:09:07Z',
#    'uid': '196098',
#    'user': 'xsintrik',
#    'version': '2'},
#   'id': '55453712',
#   'pos': [29.3349071, -94.7802776],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:06:18Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453713',
#   'pos': [29.3347638, -94.7803009],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:06:19Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453718',
#   'pos': [29.3346213, -94.780479],
#   'type': 'node'},
#  {'created': {'changeset': '479527',
#    'timestamp': '2007-09-20T21:06:19Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '55453723',
#   'pos': [29.3342295, -94.7806215],
#   'type': 'node'},
#  {'created': {'changeset': '5051907',
#    'timestamp': '2010-06-22T15:09:22Z',
#    'uid': '196098',
#    'user': 'xsintrik',
#    'version': '2'},
#   'id': '55453726',
#   'pos': [29.3341495, -94.7810929],
#   'type': 'node'},
#  {'created': {'changeset': '5051907',
#    'timestamp': '2010-06-22T15:09:22Z',
#    'uid': '196098',
#    'user': 'xsintrik',
#    'version': '2'},
#   'id': '55453731',
#   'pos': [29.3341775, -94.7816938],
#   'type': 'node'},
#  {'created': {'changeset': '5051907',
#    'timestamp': '2010-06-22T15:09:22Z',
#    'uid': '196098',
#    'user': 'xsintrik',
#    'version': '2'},
#   'id': '55453733',
#   'pos': [29.3342337, -94.7823589],
#   'type': 'node'},
#  {'created': {'changeset': '5051907',
#    'timestamp': '2010-06-22T15:09:22Z',
#    'uid': '196098',
#    'user': 'xsintrik',
#    'version': '2'},
#   'id': '55453737',
#   'pos': [29.3343366, -94.782992],
#   'type': 'node'},
#  {'created': {'changeset': '5051907',
#    'timestamp': '2010-06-22T15:09:23Z',
#    'uid': '196098',
#    'user': 'xsintrik',
#    'version': '2'},
#   'id': '55453741',
#   'pos': [29.334561, -94.7837966],
#   'type': 'node'},
#  {'created': {'changeset': '5051907',
#    'timestamp': '2010-06-22T15:09:23Z',
#    'uid': '196098',
#    'user': 'xsintrik',
#    'version': '2'},
#   'id': '55453744',
#   'pos': [29.3347761, -94.784258],
#   'type': 'node'},
#  {'created': {'changeset': '5051907',
#    'timestamp': '2010-06-22T15:09:23Z',
#    'uid': '196098',
#    'user': 'xsintrik',
#    'version': '2'},
#   'id': '55453748',
#   'pos': [29.3351035, -94.7849339],
#   'type': 'node'},
#  {'created': {'changeset': '5051907',
#    'timestamp': '2010-06-22T15:09:23Z',
#    'uid': '196098',
#    'user': 'xsintrik',
#    'version': '2'},
#   'id': '55453751',
#   'pos': [29.3354496, -94.785524],
#   'type': 'node'},
#  {'created': {'changeset': '5051907',
#    'timestamp': '2010-06-22T15:09:23Z',
#    'uid': '196098',
#    'user': 'xsintrik',
#    'version': '2'},
#   'id': '55453756',
#   'pos': [29.3359079, -94.7861999],
#   'type': 'node'},
#  {'created': {'changeset': '5051907',
#    'timestamp': '2010-06-22T15:09:23Z',
#    'uid': '196098',
#    'user': 'xsintrik',
#    'version': '2'},
#   'id': '55453761',
#   'pos': [29.3361791, -94.7865325],
#   'type': 'node'},
#  {'created': {'changeset': '5051907',
#    'timestamp': '2010-06-22T15:09:23Z',
#    'uid': '196098',
#    'user': 'xsintrik',
#    'version': '2'},
#   'id': '55453766',
#   'pos': [29.3365626, -94.786908],
#   'type': 'node'},
#  {'created': {'changeset': '5051907',
#    'timestamp': '2010-06-22T15:09:23Z',
#    'uid': '196098',
#    'user': 'xsintrik',
#    'version': '2'},
#   'id': '55453771',
#   'pos': [29.3369835, -94.78738],
#   'type': 'node'},
#  {'created': {'changeset': '5051907',
#    'timestamp': '2010-06-22T15:09:23Z',
#    'uid': '196098',
#    'user': 'xsintrik',
#    'version': '2'},
#   'id': '55453777',
#   'pos': [29.3374979, -94.7878414],
#   'type': 'node'},
#  {'created': {'changeset': '5051907',
#    'timestamp': '2010-06-22T15:09:23Z',
#    'uid': '196098',
#    'user': 'xsintrik',
#    'version': '2'},
#   'id': '55453780',
#   'pos': [29.3380871, -94.78841],
#   'type': 'node'},
#  {'created': {'changeset': '5051907',
#    'timestamp': '2010-06-22T15:09:24Z',
#    'uid': '196098',
#    'user': 'xsintrik',
#    'version': '2'},
#   'id': '55453784',
#   'pos': [29.3385734, -94.7889465],
#   'type': 'node'},
#  {'created': {'changeset': '5051907',
#    'timestamp': '2010-06-22T15:09:24Z',
#    'uid': '196098',
#    'user': 'xsintrik',
# ...
#    'timestamp': '2007-10-19T16:24:24Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '79924880',
#   'pos': [29.3252706, -94.7392399],
#   'type': 'node'},
#  {'created': {'changeset': '257036',
#    'timestamp': '2007-10-19T16:24:24Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '79924889',
#   'pos': [29.3257747, -94.7392159],
#   'type': 'node'},
#  {'created': {'changeset': '257036',
#    'timestamp': '2007-10-19T16:24:25Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '79924897',
#   'pos': [29.3264589, -94.7387478],
#   'type': 'node'},
#  {'created': {'changeset': '257036',
#    'timestamp': '2007-10-19T16:24:25Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '79924908',
#   'pos': [29.327143, -94.7380156],
#   'type': 'node'},
#  {'created': {'changeset': '257036',
#    'timestamp': '2007-10-19T16:24:25Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '79924916',
#   'pos': [29.3280552, -94.7369954],
#   'type': 'node'},
#  {'created': {'changeset': '257036',
#    'timestamp': '2007-10-19T16:24:26Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '79924926',
#   'pos': [29.3285593, -94.7358912],
#   'type': 'node'},
#  {'created': {'changeset': '257036',
#    'timestamp': '2007-10-19T16:24:26Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '79924935',
#   'pos': [29.3290995, -94.735267],
#   'type': 'node'},
#  {'created': {'changeset': '257036',
#    'timestamp': '2007-10-19T16:24:27Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '79924943',
#   'pos': [29.3296276, -94.7348709],
#   'type': 'node'},
#  {'created': {'changeset': '257036',
#    'timestamp': '2007-10-19T16:24:27Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '79924951',
#   'pos': [29.3298946, -94.7347779],
#   'type': 'node'},
#  {'created': {'changeset': '257036',
#    'timestamp': '2007-10-19T16:24:27Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '79924965',
#   'pos': [29.3299546, -94.7348619],
#   'type': 'node'},
#  {'created': {'changeset': '257036',
#    'timestamp': '2007-10-19T16:24:28Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '79924974',
#   'pos': [29.3298766, -94.735036],
#   'type': 'node'},
#  {'created': {'changeset': '257036',
#    'timestamp': '2007-10-19T16:24:28Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '79924979',
#   'pos': [29.3299426, -94.735174],
#   'type': 'node'},
#  {'created': {'changeset': '257036',
#    'timestamp': '2007-10-19T16:24:28Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '79924990',
#   'pos': [29.3303627, -94.7355101],
#   'type': 'node'},
#  {'created': {'changeset': '257036',
#    'timestamp': '2007-10-19T16:24:29Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '79924998',
#   'pos': [29.3328933, -94.7317564],
#   'type': 'node'},
#  {'created': {'changeset': '257036',
#    'timestamp': '2007-10-19T16:24:29Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '79925009',
#   'pos': [29.3331161, -94.7317288],
#   'type': 'node'},
#  {'created': {'changeset': '257036',
#    'timestamp': '2007-10-19T16:24:29Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '79925022',
#   'pos': [29.3335654, -94.7315072],
#   'type': 'node'},
#  {'created': {'changeset': '257036',
#    'timestamp': '2007-10-19T16:24:30Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '79925030',
#   'pos': [29.3339127, -94.7312669],
#   'type': 'node'},
#  {'created': {'changeset': '257036',
#    'timestamp': '2007-10-19T16:24:30Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '79925037',
#   'pos': [29.3349244, -94.7311217],
#   'type': 'node'},
#  {'created': {'changeset': '257036',
#    'timestamp': '2007-10-19T16:24:30Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '79925050',
#   'pos': [29.3352519, -94.7309235],
#   'type': 'node'},
#  {'created': {'changeset': '257036',
#    'timestamp': '2007-10-19T16:24:31Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '79925059',
#   'pos': [29.3357286, -94.7309958],
#   'type': 'node'},
#  {'created': {'changeset': '257036',
#    'timestamp': '2007-10-19T16:24:31Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '79925068',
#   'pos': [29.3354975, -94.7308513],
#   'type': 'node'},
#  {'created': {'changeset': '257036',
#    'timestamp': '2007-10-19T17:43:07Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '80029566',
#   'leisure': 'park',
#   'name': 'Stewart Beach Park',
#   'natural': 'beach',
#   'pos': [29.3060929, -94.7679897],
#   'type': 'node'},
#  {'created': {'changeset': '9214891',
#    'timestamp': '2011-09-05T07:10:18Z',
#    'uid': '119881',
#    'user': 'claysmalley',
#    'version': '3'},
#   'id': '80029577',
#   'pos': [29.3051904, -94.7722181],
#   'type': 'node'},
#  {'created': {'changeset': '13322277',
#    'timestamp': '2012-10-01T13:22:24Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '2'},
#   'id': '80029698',
#   'pos': [29.3079001, -94.7734362],
#   'type': 'node'},
#  {'created': {'changeset': '13322277',
#    'timestamp': '2012-10-01T13:22:25Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '2'},
#   'id': '80029801',
#   'pos': [29.3078666, -94.7735712],
#   'type': 'node'},
#  {'created': {'changeset': '13322277',
#    'timestamp': '2012-10-01T13:22:25Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '2'},
#   'id': '80029829',
#   'pos': [29.3065517, -94.7731135],
#   'type': 'node'},
#  {'created': {'changeset': '22073489',
#    'timestamp': '2014-05-01T21:31:05Z',
#    'uid': '1110270',
#    'user': 'afdreher',
#    'version': '3'},
#   'id': '80029841',
#   'pos': [29.3061319, -94.7729708],
#   'type': 'node'},
#  {'created': {'changeset': '257036',
#    'timestamp': '2007-10-19T17:43:16Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '80029854',
#   'pos': [29.3053308, -94.7726859],
#   'type': 'node'},
#  {'created': {'changeset': '16869217',
#    'timestamp': '2013-07-08T07:03:34Z',
#    'uid': '243003',
#    'user': 'skquinn',
#    'version': '4'},
#   'highway': 'traffic_signals',
#   'id': '80041653',
#   'pos': [29.3050619, -94.772629],
#   'type': 'node'},
#  {'created': {'changeset': '9214891',
#    'timestamp': '2011-09-05T07:10:22Z',
#    'uid': '119881',
#    'user': 'claysmalley',
#    'version': '2'},
#   'id': '80041657',
#   'pos': [29.3049398, -94.7726296],
#   'type': 'node'},
#  {'created': {'changeset': '257036',
#    'timestamp': '2007-10-19T17:53:29Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '80041661',
#   'pos': [29.3047757, -94.7726529],
#   'type': 'node'},
#  {'created': {'changeset': '22013407',
#    'timestamp': '2014-04-29T01:13:05Z',
#    'uid': '1110270',
#    'user': 'afdreher',
#    'version': '2'},
#   'id': '80041664',
#   'pos': [29.3046142, -94.7727237],
#   'type': 'node'},
#  {'created': {'changeset': '22013407',
#    'timestamp': '2014-04-29T01:13:05Z',
#    'uid': '1110270',
#    'user': 'afdreher',
#    'version': '2'},
#   'id': '80041670',
#   'pos': [29.3044692, -94.7728015],
#   'type': 'node'},
#  {'created': {'changeset': '13322277',
#    'timestamp': '2012-10-01T13:22:25Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '3'},
#   'id': '80054527',
#   'pos': [29.296282, -94.7807163],
#   'type': 'node'},
#  {'created': {'changeset': '13322277',
#    'timestamp': '2012-10-01T13:22:25Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '2'},
#   'id': '80054533',
#   'pos': [29.295989, -94.78186],
#   'type': 'node'},
#  {'created': {'changeset': '13322277',
#    'timestamp': '2012-10-01T13:22:25Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '2'},
#   'id': '80054540',
#   'pos': [29.2956643, -94.7830186],
#   'type': 'node'},
#  {'created': {'changeset': '13322277',
#    'timestamp': '2012-10-01T13:22:25Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '2'},
#   'id': '80054545',
#   'pos': [29.2953886, -94.7841532],
#   'type': 'node'},
#  {'created': {'changeset': '13322277',
#    'timestamp': '2012-10-01T13:22:25Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '2'},
#   'id': '80054550',
#   'pos': [29.2950916, -94.7852909],
#   'type': 'node'},
#  {'created': {'changeset': '13322277',
#    'timestamp': '2012-10-01T13:22:25Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '2'},
#   'id': '80054559',
#   'pos': [29.2947966, -94.7864345],
#   'type': 'node'},
#  {'created': {'changeset': '26168780',
#    'timestamp': '2014-10-18T11:58:41Z',
#    'uid': '243003',
#    'user': 'skquinn',
#    'version': '3'},
#   'highway': 'traffic_signals',
#   'id': '80054565',
#   'pos': [29.294481, -94.787585],
#   'type': 'node'},
#  {'created': {'changeset': '13322277',
#    'timestamp': '2012-10-01T13:22:26Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '2'},
#   'id': '80054572',
#   'pos': [29.294196, -94.788688],
#   'type': 'node'},
#  {'created': {'changeset': '13289030',
#    'timestamp': '2012-09-28T19:14:35Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '2'},
#   'id': '80054579',
#   'pos': [29.293894, -94.789869],
#   'type': 'node'},
#  {'created': {'changeset': '5009783',
#    'timestamp': '2010-06-17T16:17:29Z',
#    'uid': '37392',
#    'user': '25or6to4',
#    'version': '2'},
#   'id': '80054586',
#   'pos': [29.2935911, -94.7909926],
#   'type': 'node'},
#  {'created': {'changeset': '13289030',
#    'timestamp': '2012-09-28T19:14:35Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '2'},
#   'id': '80054604',
#   'pos': [29.292075, -94.796831],
#   'type': 'node'},
#  {'created': {'changeset': '13289030',
#    'timestamp': '2012-09-28T19:14:35Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '2'},
#   'id': '80054609',
#   'pos': [29.291773, -94.797988],
#   'type': 'node'},
#  {'created': {'changeset': '13289030',
#    'timestamp': '2012-09-28T19:14:35Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '2'},
#   'id': '80054615',
#   'pos': [29.2914715, -94.7991194],
#   'type': 'node'},
#  {'created': {'changeset': '13289030',
#    'timestamp': '2012-09-28T19:14:35Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '2'},
#   'id': '80054618',
#   'pos': [29.2911634, -94.8003017],
#   'type': 'node'},
#  {'created': {'changeset': '13289030',
#    'timestamp': '2012-09-28T19:14:35Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '2'},
#   'id': '80054623',
#   'pos': [29.2908723, -94.8013946],
#   'type': 'node'},
#  {'created': {'changeset': '13289030',
#    'timestamp': '2012-09-28T19:14:35Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '3'},
#   'id': '80054632',
#   'pos': [29.2905632, -94.8025803],
#   'type': 'node'},
#  {'created': {'changeset': '5009783',
#    'timestamp': '2010-06-17T17:10:04Z',
#    'uid': '37392',
#    'user': '25or6to4',
#    'version': '2'},
#   'id': '80054697',
#   'pos': [29.2899419, -94.8048596],
#   'type': 'node'},
#  {'created': {'changeset': '10938875',
#    'timestamp': '2012-03-11T04:06:12Z',
#    'uid': '239998',
#    'user': 'Sundance',
#    'version': '2'},
#   'id': '80054712',
#   'pos': [29.2893867, -94.807113],
#   'type': 'node'},
#  {'created': {'changeset': '10938875',
#    'timestamp': '2012-03-11T04:06:12Z',
#    'uid': '239998',
#    'user': 'Sundance',
#    'version': '2'},
#   'id': '80054733',
#   'pos': [29.2875843, -94.8139804],
#   'type': 'node'},
#  {'created': {'changeset': '13288715',
#    'timestamp': '2012-09-28T18:47:46Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '2'},
#   'id': '80054737',
#   'pos': [29.286971, -94.816263],
#   'type': 'node'},
#  {'created': {'changeset': '13288715',
#    'timestamp': '2012-09-28T18:47:46Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '2'},
#   'id': '80054748',
#   'pos': [29.286674, -94.817393],
#   'type': 'node'},
#  {'created': {'changeset': '13288715',
#    'timestamp': '2012-09-28T18:47:46Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '2'},
#   'id': '80054756',
#   'pos': [29.2863714, -94.8185442],
#   'type': 'node'},
#  {'created': {'changeset': '13288715',
#    'timestamp': '2012-09-28T18:47:46Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '2'},
#   'id': '80054763',
#   'pos': [29.2860728, -94.8196871],
#   'type': 'node'},
#  {'created': {'changeset': '13288715',
#    'timestamp': '2012-09-28T18:47:46Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '2'},
#   'id': '80054771',
#   'pos': [29.2857733, -94.8208198],
#   'type': 'node'},
#  {'created': {'changeset': '13288715',
#    'timestamp': '2012-09-28T18:47:47Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '2'},
#   'id': '80054777',
#   'pos': [29.2854727, -94.8219622],
#   'type': 'node'},
#  {'created': {'changeset': '13288715',
#    'timestamp': '2012-09-28T18:47:47Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '2'},
#   'id': '80054791',
#   'pos': [29.2851748, -94.8231129],
#   'type': 'node'},
#  {'created': {'changeset': '13288897',
#    'timestamp': '2012-09-28T19:02:16Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '2'},
#   'id': '80054805',
#   'pos': [29.2845671, -94.8253991],
#   'type': 'node'},
#  {'created': {'changeset': '13288897',
#    'timestamp': '2012-09-28T19:02:16Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '2'},
#   'id': '80054818',
#   'pos': [29.284273, -94.826529],
#   'type': 'node'},
#  {'created': {'changeset': '13288897',
#    'timestamp': '2012-09-28T19:02:16Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '2'},
#   'id': '80054833',
#   'pos': [29.2839642, -94.8276774],
#   'type': 'node'},
#  {'created': {'changeset': '257036',
#    'timestamp': '2007-10-19T18:14:24Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '80072748',
#   'pos': [29.2934648, -94.7842519],
#   'type': 'node'},
#  {'created': {'changeset': '257036',
#    'timestamp': '2007-10-19T18:14:25Z',
#    'uid': '13871',
#    'user': 'Daniel P',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '80072752',
#   'pos': [29.2935368, -94.7838858],
#   'type': 'node'},
#  {'created': {'changeset': '13322277',
#    'timestamp': '2012-10-01T13:22:26Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '2'},
#   'id': '80072757',
#   'pos': [29.2933568, -94.784696],
#   'type': 'node'},
#  {'created': {'changeset': '13322277',
#    'timestamp': '2012-10-01T13:22:26Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '2'},
#   'id': '80072771',
#   'pos': [29.293047, -94.78584],
#   'type': 'node'},
#  {'created': {'changeset': '26168780',
#    'timestamp': '2014-10-18T11:58:41Z',
#    'uid': '243003',
#    'user': 'skquinn',
#    'version': '3'},
#   'highway': 'traffic_signals',
#   'id': '80072778',
#   'pos': [29.292752, -94.786993],
#   'type': 'node'},
#  {'created': {'changeset': '13322277',
#    'timestamp': '2012-10-01T13:22:26Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '2'},
#   'id': '80072787',
#   'pos': [29.292462, -94.788109],
#   'type': 'node'},
#  {'created': {'changeset': '13289030',
#    'timestamp': '2012-09-28T19:14:35Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '2'},
#   'id': '80072801',
#   'pos': [29.2921515, -94.7892656],
#   'type': 'node'},
#  {'created': {'changeset': '13289030',
#    'timestamp': '2012-09-28T19:14:35Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '2'},
#   'id': '80072813',
#   'pos': [29.2918588, -94.7904051],
#   'type': 'node'},
#  {'created': {'changeset': '13289030',
#    'timestamp': '2012-09-28T19:14:35Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '2'},
#   'id': '80072824',
#   'pos': [29.29123, -94.792807],
#   'type': 'node'},
#  ...]

# %% [markdown]
# # Import json file into MongoDB

# %% [raw]
# Importing json file into mongo
# # start a mongod instance using ./mongod
# # open new terminal window and cd to mongo bin folder
# # move records from json to mongo like this..
# # ./mongoimport --db test --collection Houston108 --file C:\Users\yepeng\Downloads\Houston_texas.osm.json

# %% [markdown]
# # 2. Data overview after cleaning

# %% [raw]
# Postal_code_sort and city_sort show that this metro extract would perhaps be more aptly named “Metrolina” or the “Houston Metropolitan Area” for its inclusion of surrounding cities in the sprawl.So, there will be postal codes unexpected in the postal code list of Houston.

# %%
from pymongo import MongoClient

# %%
client = MongoClient()
db = client.test

# %%
postal_code_sort = db.Houston111.aggregate([{"$match":{"address.postcode":{"$exists":1}}},
                                          {"$group":{"_id":"$address.postcode",
                                                     "count":{"$sum":1}}}, 
                                          {"$sort":{"count":-1}}])

# %%
for p in postal_code_sort:
    print p
# Out:
# {u'count': 481, u'_id': 77096}
# {u'count': 253, u'_id': 77449}
# {u'count': 211, u'_id': 77401}
# {u'count': 184, u'_id': 77339}
# {u'count': 174, u'_id': 77494}
# {u'count': 97, u'_id': 77002}
# {u'count': 83, u'_id': 77079}
# {u'count': 83, u'_id': 77076}
# {u'count': 80, u'_id': 77396}
# {u'count': 69, u'_id': 77006}
# {u'count': 66, u'_id': 77338}
# {u'count': 65, u'_id': 77030}
# {u'count': 63, u'_id': 77090}
# {u'count': 61, u'_id': 77060}
# {u'count': 50, u'_id': 77032}
# {u'count': 46, u'_id': 77586}
# {u'count': 45, u'_id': 77070}
# {u'count': 44, u'_id': 77008}
# {u'count': 41, u'_id': 77084}
# {u'count': 40, u'_id': 77027}
# {u'count': 39, u'_id': 77024}
# {u'count': 39, u'_id': 77459}
# {u'count': 37, u'_id': 77479}
# {u'count': 37, u'_id': 77007}
# {u'count': 35, u'_id': 77204}
# {u'count': 33, u'_id': 77573}
# {u'count': 32, u'_id': 77489}
# {u'count': 32, u'_id': 77478}
# {u'count': 31, u'_id': 77345}
# {u'count': 30, u'_id': 77380}
# {u'count': 27, u'_id': 77004}
# {u'count': 27, u'_id': 77346}
# {u'count': 25, u'_id': 77022}
# {u'count': 25, u'_id': 77429}
# {u'count': 23, u'_id': 77074}
# {u'count': 23, u'_id': 77056}
# {u'count': 22, u'_id': 77005}
# {u'count': 21, u'_id': 77085}
# {u'count': 21, u'_id': 77093}
# {u'count': 21, u'_id': 77450}
# {u'count': 21, u'_id': 77550}
# {u'count': 20, u'_id': 77520}
# {u'count': 20, u'_id': 77025}
# {u'count': 20, u'_id': 77058}
# {u'count': 18, u'_id': 77498}
# {u'count': 18, u'_id': 77057}
# {u'count': 17, u'_id': 77530}
# {u'count': 17, u'_id': 77386}
# {u'count': 16, u'_id': 77566}
# {u'count': 16, u'_id': 77571}
# {u'count': 16, u'_id': 77379}
# {u'count': 15, u'_id': 77535}
# {u'count': 15, u'_id': 77477}
# {u'count': 15, u'_id': 77536}
# {u'count': 14, u'_id': 77584}
# {u'count': 13, u'_id': 77067}
# {u'count': 13, u'_id': 77010}
# {u'count': 13, u'_id': 77098}
# {u'count': 13, u'_id': 77063}
# {u'count': 13, u'_id': 77598}
# {u'count': 13, u'_id': 77019}
# {u'count': 13, u'_id': 77377}
# {u'count': 13, u'_id': 77077}
# {u'count': 12, u'_id': 77384}
# {u'count': 12, u'_id': 77546}
# {u'count': 12, u'_id': 77521}
# {u'count': 12, u'_id': 77551}
# {u'count': 12, u'_id': 77036}
# {u'count': 12, u'_id': 77493}
# {u'count': 11, u'_id': 77375}
# {u'count': 11, u'_id': 77054}
# {u'count': 11, u'_id': 77040}
# {u'count': 11, u'_id': 77064}
# {u'count': 11, u'_id': 77055}
# {u'count': 11, u'_id': 77373}
# {u'count': 11, u'_id': 77009}
# {u'count': 10, u'_id': 77018}
# {u'count': 10, u'_id': 77354}
# {u'count': 9, u'_id': 77539}
# {u'count': 9, u'_id': 77042}
# {u'count': 9, u'_id': 77080}
# {u'count': 9, u'_id': 77092}
# {u'count': 9, u'_id': 77043}
# {u'count': 9, u'_id': 77065}
# {u'count': 9, u'_id': 77554}
# {u'count': 9, u'_id': 77095}
# {u'count': 8, u'_id': 77062}
# {u'count': 8, u'_id': 77020}
# {u'count': 8, u'_id': 77003}
# {u'count': 8, u'_id': 77433}
# {u'count': 8, u'_id': 77091}
# {u'count': 7, u'_id': 77059}
# {u'count': 7, u'_id': 77038}
# {u'count': 7, u'_id': 77381}
# {u'count': 7, u'_id': 77035}
# {u'count': 7, u'_id': 77069}
# {u'count': 7, u'_id': 77581}
# {u'count': 7, u'_id': 77407}
# {u'count': 6, u'_id': 77471}
# {u'count': 6, u'_id': 77011}
# {u'count': 6, u'_id': 77505}
# {u'count': 6, u'_id': 77041}
# {u'count': 6, u'_id': 77072}
# {u'count': 5, u'_id': 77037}
# {u'count': 5, u'_id': 77406}
# {u'count': 5, u'_id': 77515}
# {u'count': 5, u'_id': 77081}
# {u'count': 5, u'_id': 77099}
# {u'count': 5, u'_id': 77071}
# {u'count': 5, u'_id': 77083}
# {u'count': 5, u'_id': 77385}
# {u'count': 5, u'_id': 77382}
# {u'count': 5, u'_id': 77082}
# {u'count': 5, u'_id': 77511}
# {u'count': 4, u'_id': 77021}
# {u'count': 4, u'_id': 77665}
# {u'count': 4, u'_id': 77469}
# {u'count': 4, u'_id': 77089}
# {u'count': 4, u'_id': 77044}
# {u'count': 4, u'_id': 77388}
# {u'count': 4, u'_id': 77087}
# {u'count': 4, u'_id': 77575}
# {u'count': 4, u'_id': 77510}
# {u'count': 4, u'_id': 77506}
# {u'count': 4, u'_id': u'77007'}
# {u'count': 4, u'_id': u'77339'}
# {u'count': 3, u'_id': 77039}
# {u'count': 3, u'_id': 77503}
# {u'count': 3, u'_id': 77086}
# {u'count': 3, u'_id': 77532}
# {u'count': 3, u'_id': 77583}
# {u'count': 3, u'_id': 77073}
# {u'count': 3, u'_id': 77031}
# {u'count': 3, u'_id': 77015}
# {u'count': 3, u'_id': 77066}
# {u'count': 3, u'_id': 77034}
# {u'count': 3, u'_id': 77014}
# {u'count': 3, u'_id': 77045}
# {u'count': 3, u'_id': 77502}
# {u'count': 3, u'_id': 77414}
# {u'count': 3, u'_id': 77590}
# {u'count': 3, u'_id': 77094}
# {u'count': 3, u'_id': 77016}
# {u'count': 2, u'_id': 77565}
# {u'count': 2, u'_id': 77049}
# {u'count': 2, u'_id': 77061}
# {u'count': 2, u'_id': 77389}
# {u'count': 2, u'_id': 77523}
# {u'count': 2, u'_id': 77531}
# {u'count': 2, u'_id': 77650}
# {u'count': 2, u'_id': 77504}
# {u'count': 2, u'_id': 77023}
# {u'count': 2, u'_id': 77474}
# {u'count': 2, u'_id': 77075}
# {u'count': 2, u'_id': u'773345'}
# {u'count': 2, u'_id': u'71000'}
# {u'count': 2, u'_id': u'77024'}
# {u'count': 1, u'_id': 77422}
# {u'count': 1, u'_id': 74404}
# {u'count': 1, u'_id': 73032}
# {u'count': 1, u'_id': 77046}
# {u'count': 1, u'_id': 77363}
# {u'count': 1, u'_id': 77068}
# {u'count': 1, u'_id': 77365}
# {u'count': 1, u'_id': 77568}
# {u'count': 1, u'_id': 77028}
# {u'count': 1, u'_id': 77492}
# {u'count': 1, u'_id': 77486}
# {u'count': 1, u'_id': 77461}
# {u'count': 1, u'_id': 77012}
# {u'count': 1, u'_id': 77580}
# {u'count': 1, u'_id': 77357}
# {u'count': 1, u'_id': 77029}
# {u'count': 1, u'_id': 77013}
# {u'count': 1, u'_id': 75057}
# {u'count': 1, u'_id': 77355}
# {u'count': 1, u'_id': 77246}
# {u'count': 1, u'_id': 77047}
# {u'count': 1, u'_id': 77485}
# {u'count': 1, u'_id': 77541}
# {u'count': 1, u'_id': 77553}
# {u'count': 1, u'_id': 77802}
# {u'count': 1, u'_id': 88581}
# {u'count': 1, u'_id': u'77019'}
# {u'count': 1, u'_id': u'77494'}
# {u'count': 1, u'_id': u'77009'}
# {u'count': 1, u'_id': u'77086'}
# {u'count': 1, u'_id': u'77036'}
# {u'count': 1, u'_id': u'77027'}
# {u'count': 1, u'_id': u'77584'}
# {u'count': 1, u'_id': u'77478'}
# {u'count': 1, u'_id': u'77054'}
# {u'count': 1, u'_id': u'77005'}
# {u'count': 1, u'_id': u'77025'}
# {u'count': 1, u'_id': u'77077'}
# {u'count': 1, u'_id': u'77042'}
# {u'count': 1, u'_id': u'77459'}
# {u'count': 1, u'_id': u'77386'}

# %%
city_sort = db.Houston111.aggregate([{"$match":{"address.city":{"$exists":1}}}, {"$group":{"_id":"$address.city", "count":{"$sum":1}}}, {"$sort":{"count":1}}])
i = 0
for c in city_sort:
    if i < 2:
        print c
        i = i +1
# Out:
# {u'count': 1, u'_id': u'Laks Jackson'}
# {u'count': 1, u'_id': u'Plantersville'}

# %% [raw]
# Now we need to start running queries to find our trouble spots in the data
# # Number of records
# # Number of unique users
# # Number of nodes and ways
# # Number of chosen type of nodes (amenities, schools, cafes, etc.)

# %% [markdown]
# #Number of ddocuments,nodes and ways

# %%
print "The total number of documents: {0}".format(db.Houston111.find().count())
print "The total number of nodes: {0}".format(db.Houston111.find({"type" : "node"}).count())
print "The total number of ways: {0}".format(db.Houston111.find({"type" : "way"}).count())
# Out:
# The total number of documents: 3209780
# The total number of nodes: 2865564
# The total number of ways: 344195

# %%
number_of_unique_users = db.Houston111.aggregate([
                                          {"$group" : {
                                             "_id" : "$created.user",
                                             "count" : {"$sum" : 1}
                                                      }
                                          }])
top_5_users = db.Houston111.aggregate([
                                      {"$group" : {
                                            "_id" : "$created.user",
                                            "count" : {"$sum" : 1}
                                      }},
                                      {"$sort" : {"count" : -1}},
                                      {"$limit" : 5 }
                                     ])
five_most_popular_amenities = db.Houston111.aggregate([{"$match" : {"amenity" : {"$exists" : 1}}},
                                                      {"$group" : {"_id" : "$amenity",
                                                                  "count" : {"$sum" : 1}}
                                                      },
                                                      {"$sort" : {"count" : -1}},
                                                      {"$limit" : 5}
                                                     ])


distinct_amenities = db.Houston111.distinct("amenity")
number_of_amenities = len(distinct_amenities)
number_of_schools = int(db.Houston111.find({"amenity" : "school"}).count())
number_of_cafes = int(db.Houston111.find({"amenity" : "cafe"}).count())

# %% [markdown]
# #Number of Unique users in Houston, TX

# %%
user_count = 0
for doc in number_of_unique_users: user_count += 1
print user_count
# Out:
# 1283

# %% [markdown]
# #The five most popular amenities in Houston, TX

# %%
for doc in five_most_popular_amenities: print doc
# Out:
# {u'count': 3496, u'_id': u'parking'}
# {u'count': 2452, u'_id': u'place_of_worship'}
# {u'count': 1649, u'_id': u'school'}
# {u'count': 904, u'_id': u'fast_food'}
# {u'count': 828, u'_id': u'restaurant'}

# %% [markdown]
# #The top 5 contributing users

# %%
for doc in top_5_users: print doc
# Out:
# {u'count': 591156, u'_id': u'woodpeck_fixbot'}
# {u'count': 547958, u'_id': u'TexasNHD'}
# {u'count': 425099, u'_id': u'afdreher'}
# {u'count': 199984, u'_id': u'scottyc'}
# {u'count': 193936, u'_id': u'cammace'}

# %% [markdown]
# #Numbers of schools,cafes and distinct amenities

# %%
print "The total number of schools: {0}".format(number_of_schools)
print "The number of cafes: {0}".format(number_of_cafes)
print "The number of distinct amenities: {0}".format(len(distinct_amenities))
# Out:
# The total number of schools: 1649
# The number of cafes: 126
# The number of distinct amenities: 98

# %%
# Number of users appearing only once (having 1 post)                                               
one_post_user = db.Houston111.aggregate([{"$group":{"_id":"$created.user", "count":{"$sum":1}}}, {"$group":{"_id":"$count", "num_users":{"$sum":1}}}, {"$sort":{"_id":1}}, {"$limit":1}])

# “_id” represents postcount
for user in one_post_user:
    print user
# Out:
# {u'num_users': 248, u'_id': 1}

# %% [markdown]
# # 3. Getting stats from dataset

# %% [raw]
# ### Contributor statistics and gamification suggestion
#
# The contributions of users seems incredibly skewed, possibly due to automated versus manual map editing (the word “bot” appears in some usernames). Here are some user percentage statistics:
#
# Top user contribution percentage (“woodpeck_fixbot”) - 18.42%
# Combined top 2 users' contribution (“jumbanho” and “woodpeck_fixbot”) - 35.49%
# Combined Top 5 users contribution - 61.01%
# Combined number of users making up only 0.0077% of posts - 248 (about 20% of all users)
#
# Thinking about these user percentages, I’m reminded of “gamification” as a motivating force for contribution. In the context of the OpenStreetMap, if user data were more prominently displayed, perhaps others would take an initiative in submitting more edits to the map. And, if everyone sees that only a handful of power users are creating more than 60% a of given map, that might spur the creation of more efficient bots, especially if certain gamification elements were present, such as rewards, badges, or a leaderboard.

# %% [markdown]
# # 4.Additional data exploration using MongoDB queries

# %%
#Biggest religion (no surprise here)
                                                
biggest_religion = db.Houston111.aggregate([{"$match":{"amenity":{"$exists":1}, "amenity":"place_of_worship"}},
                                                
{"$group":{"_id":"$religion", "count":{"$sum":1}}},
                                                
{"$sort":{"count":-1}}, {"$limit":1}])

for b in biggest_religion:
    print b
# Out:
# {u'count': 2376, u'_id': u'christian'}

# %%
# Most popular cuisines
                                                
most_pop_cuisine = db.Houston111.aggregate([{"$match":{"amenity":{"$exists":1}, "amenity":"restaurant"}},
                     {"$group":{"_id":"$cuisine", "count":{"$sum":1}}},
                     {"$sort":{"count":-1}}, {"$limit":2}])
for m in most_pop_cuisine:
    print m
# Out:
# {u'count': 399, u'_id': None}
# {u'count': 82, u'_id': u'mexican'}

# %% [markdown]
# # 5.Conclusion

# %% [markdown]
# After this review of the data it’s obvious that the Houston metro area is incomplete, though I believe it has been well cleaned for the purposes of this exercise. It interests me to notice a fair amount of GPS data makes it into OpenStreetMap.org on account of users’ efforts, whether by scripting a map editing bot or otherwise. With a rough GPS data processor in place and working together with a more robust data processor similar to data.py I think it would be possible to input a great amount of cleaned data to OpenStreetMap.org.
#
# Another interesting problem is that the query result about most popupar cuisine are "None"(399) and "Mexican"(82).If there is more information collected about the unknown type of cuisine it will be better for people to know more about the favarite food of Houston residents. Especially for people who want to invest a restaurant such imformtion is very important.
